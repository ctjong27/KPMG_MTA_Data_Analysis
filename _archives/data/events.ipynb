# %%
# ee00072cbc4d403ba115db35c1725eb4

# %%
import requests

# Set up the API endpoint URL
url = 'https://api.nyc.gov/calendar/search'

# Set up the query parameters
params = {
    'startDate': '2022-03-01',
    'endDate': '2022-03-31',
    'agency': 'Parks Department',
    'boroughs': 'Manhattan,Brooklyn',
    'categories': 'Concerts,Exhibitions',
    'sort': 'startDateAsc',
    'pageNumber': '1',
}

# Make the API request
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Print out the events data
    data = response.json()
    for event in data['items']:
        print(event['title'])
else:
    print('Error: Unable to retrieve events data')
# Out:
# Error: Unable to retrieve events data

# %%
import requests

# Set up the API endpoint URL
url = 'https://api.nyc.gov/calendar/search'

# Set up the query parameters
params = {
    'startDate': '03/01/2022 12:00 AM',
    'endDate': '03/03/2023 11:59 PM',
    'sort': 'DATE',
    'pageNumber': '9',
}

# Set up the headers with the subscription key
subscription_key = 'ee00072cbc4d403ba115db35c1725eb4'
headers = {'Ocp-Apim-Subscription-Key': subscription_key}

# Make the API request
response = requests.get(url, params=params, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Print out the events data
    data = response.json()
    for event in data['items']:
        print(event['name'])
        # print(event)
else:
    print('Error: Unable to retrieve events data')
# Out:
# Forest Fitness
# Bronx Urban Nature and Nature's Beauty
# Farm Exploration Days
# Farm Exploration Days
# Bronx Urban Nature and Nature's Beauty
# Bronx Urban Nature and Nature's Beauty
# Taxi & Limousine Commission Hearing on Proposed Rules
# [NeON Works] Professionalism at Work (For Young Adults in Brownsville)
# Basic Responsibilities of Rental Property Owners
# Bronx Urban Nature and Nature's Beauty

# %%
import requests

# Set up the API endpoint URL
url = 'https://api.nyc.gov/calendar/search'

# Set up the query parameters
params = {
    'startDate': '03/01/2023 12:00 AM',
    'endDate': '03/01/2023 11:59 PM',
    'sort': 'DATE',
    'pageNumber': '1',
}

# Set up the headers with the subscription key
subscription_key = 'ee00072cbc4d403ba115db35c1725eb4'
headers = {'Ocp-Apim-Subscription-Key': subscription_key}

# Make the API request
response = requests.get(url, params=params, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Print out the events data
    data = response.json()
    for event in data['items']:
        print(event['name'])
        print(event['allDay'])
        # print(event)
else:
    print('Error: Unable to retrieve events data')
response.json()
# Out:
# NYC Off-Broadway Week
# True
# Morris Heights Farm Stand Wednesday
# False
# Chinese-American Planning Council Fresh Food Box Wednesday
# False
# City Planning Commission Public Meeting
# False
# The Orchid Show
# False
# Uptown Grand Central Food Box Wednesday
# False
# Food Protection: Lesson 1 Lab
# False
# The Value of Work
# False
# Financial Literacy 101
# False
# Life Skills: Financial Literacy (Part 1 & 2)
# False
# {'items': [{'startDate': '2023-03-01T00:01:00.000-05:00',
#    'datePart': 'Mar 1',
#    'timePart': 'All Day',
#    'canceled': False,
#    'permalink': 'https://www1.nyc.gov/events/nyc-off-broadway-week/413974/17',
#    'guid': '22acddfa-af67-46ca-85c6-4f8b25ab6bcb',
#    'id': 413974,
#    'sequence': 17,
#    'allDay': True,
#    'cityPick': True,
#    'name': 'NYC Off-Broadway Week',
# ...
