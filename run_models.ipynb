# %%
# !python ./modeling/4_25_Prophet_dependence.py
# Out:
# 13:25:00 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:00 - cmdstanpy - INFO - Chain [1] done processing
# 13:25:00 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:00 - cmdstanpy - INFO - Chain [1] done processing
# 13:25:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:01 - cmdstanpy - INFO - Chain [1] done processing
# 13:25:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:02 - cmdstanpy - INFO - Chain [1] done processing
# 13:25:02 - cmdstanpy - ERROR - Chain [1] error: error during processing Unknown error
# Optimization terminated abnormally. Falling back to Newton.
# 13:25:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:03 - cmdstanpy - INFO - Chain [1] done processing
# 13:25:03 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:03 - cmdstanpy - INFO - Chain [1] done processing
# 13:25:03 - cmdstanpy - ERROR - Chain [1] error: error during processing Unknown error
# ...

# %%
# !python ./modeling/prophet_featureimportance.py
# Out:
# Figure(1200x600)
# Figure(1200x600)
# Figure(900x900)
# Figure(1500x9500)
# Figure(1500x9500)
# 14:13:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:13:07 - cmdstanpy - INFO - Chain [1] done processing
