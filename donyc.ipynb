# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

QUERIED_TEXT = 'events'

# Prep dataframe for all applicable date ranges for which there will be total_{QUERIED_TEXT} count
queried_start_date = pd.to_datetime('2020-01-01') #, format='%Y%m%d')
queried_end_date = pd.to_datetime('2023-06-01') #, format='%Y%m%d')
queried_date_range = pd.date_range(start=queried_start_date, end=queried_end_date)
queried_date_range_df = pd.DataFrame({'date': queried_date_range})
queried_date_range_df[f'total_{QUERIED_TEXT}'] = None

# Set the base URL
base_url = 'https://donyc.com/events/{}/{}/{}?page={}'

# Verify that file exists
csv_filename = f'donyc_{QUERIED_TEXT}.csv'
if os.path.isfile(csv_filename):
    queried_date_range_df = pd.read_csv(csv_filename, parse_dates=['date'])

# Loop through each date in the date range
for i, row in queried_date_range_df.iterrows():

    date = row['date']

    # Check if the 'total_{QUERIED_TEXT}' column is not NaN, if yes then break out of the loop
    if not pd.isna(row[f'total_{QUERIED_TEXT}']):
        print(f'{date} is already populated')
        continue

    # Format the URL with the year, month, day, and page number
    year = date.year
    month = date.month
    day = date.day
    page_num = 1

    # Initialize the count to 0
    count = 0

    # Loop through each page of {QUERIED_TEXT} for the current date
    while True:
        # Make a request to the current page
        url = base_url.format(year, month, day, page_num)
        response = requests.get(url)

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all div elements with a class attribute starting with 'ds-listing event-card'
        event_cards = soup.select('div[class^="ds-listing event-card"]')

        # If no event cards are found, break out of the loop
        if not event_cards:
            break

        # Loop through each event card that matches the specified classes
        for card in event_cards:
            # Find the anchor tag with an href attribute that starts with '/{QUERIED_TEXT}/2023/3/1' and the specified classes
            anchor = card.find('a', href=lambda href: href and href.startswith('/events/{}/{}/{}'.format(year, month, day)), class_='ds-listing-event-title url summary')
            if anchor:
                count += 1

        # Increment the page number and update the URL
        print(page_num)
        page_num += 1

    # Set the count for the current date in the 'total_{QUERIED_TEXT}' column of the DataFrame
    queried_date_range_df.loc[i, f'total_{QUERIED_TEXT}'] = count
    queried_date_range_df.to_csv(csv_filename, index=False)
    print(queried_date_range_df.loc[i])
# Out:
# 2020-01-01 00:00:00 is already populated
# 2020-01-02 00:00:00 is already populated
# 2020-01-03 00:00:00 is already populated
# 2020-01-04 00:00:00 is already populated
# 2020-01-05 00:00:00 is already populated
# 2020-01-06 00:00:00 is already populated
# 2020-01-07 00:00:00 is already populated
# 2020-01-08 00:00:00 is already populated
# 2020-01-09 00:00:00 is already populated
# 2020-01-10 00:00:00 is already populated
# 2020-01-11 00:00:00 is already populated
# 2020-01-12 00:00:00 is already populated
# 2020-01-13 00:00:00 is already populated
# 2020-01-14 00:00:00 is already populated
# 2020-01-15 00:00:00 is already populated
# 2020-01-16 00:00:00 is already populated
# 2020-01-17 00:00:00 is already populated
# 2020-01-18 00:00:00 is already populated
# 2020-01-19 00:00:00 is already populated
# 2020-01-20 00:00:00 is already populated
# 2020-01-21 00:00:00 is already populated
# 2020-01-22 00:00:00 is already populated
# 2020-01-23 00:00:00 is already populated
# 2020-01-24 00:00:00 is already populated
# 2020-01-25 00:00:00 is already populated
# 2020-01-26 00:00:00 is already populated
# 2020-01-27 00:00:00 is already populated
# 2020-01-28 00:00:00 is already populated
# 2020-01-29 00:00:00 is already populated
# 2020-01-30 00:00:00 is already populated
# 2020-01-31 00:00:00 is already populated
# 2020-02-01 00:00:00 is already populated
# 2020-02-02 00:00:00 is already populated
# 2020-02-03 00:00:00 is already populated
# 2020-02-04 00:00:00 is already populated
# 2020-02-05 00:00:00 is already populated
# 2020-02-06 00:00:00 is already populated
# 2020-02-07 00:00:00 is already populated
# 2020-02-08 00:00:00 is already populated
# 2020-02-09 00:00:00 is already populated
# 2020-02-10 00:00:00 is already populated
# 2020-02-11 00:00:00 is already populated
# 2020-02-12 00:00:00 is already populated
# 2020-02-13 00:00:00 is already populated
# 2020-02-14 00:00:00 is already populated
# 2020-02-15 00:00:00 is already populated
# 2020-02-16 00:00:00 is already populated
# 2020-02-17 00:00:00 is already populated
# 2020-02-18 00:00:00 is already populated
# 2020-02-19 00:00:00 is already populated
# 2020-02-20 00:00:00 is already populated
# 2020-02-21 00:00:00 is already populated
# 2020-02-22 00:00:00 is already populated
# 2020-02-23 00:00:00 is already populated
# 2020-02-24 00:00:00 is already populated
# 2020-02-25 00:00:00 is already populated
# 2020-02-26 00:00:00 is already populated
# 2020-02-27 00:00:00 is already populated
# 2020-02-28 00:00:00 is already populated
# 2020-02-29 00:00:00 is already populated
# 2020-03-01 00:00:00 is already populated
# 2020-03-02 00:00:00 is already populated
# 2020-03-03 00:00:00 is already populated
# 2020-03-04 00:00:00 is already populated
# 2020-03-05 00:00:00 is already populated
# 2020-03-06 00:00:00 is already populated
# 2020-03-07 00:00:00 is already populated
# 2020-03-08 00:00:00 is already populated
# 2020-03-09 00:00:00 is already populated
# 2020-03-10 00:00:00 is already populated
# 2020-03-11 00:00:00 is already populated
# 2020-03-12 00:00:00 is already populated
# 2020-03-13 00:00:00 is already populated
# 2020-03-14 00:00:00 is already populated
# 2020-03-15 00:00:00 is already populated
# 2020-03-16 00:00:00 is already populated
# 2020-03-17 00:00:00 is already populated
# 2020-03-18 00:00:00 is already populated
# 2020-03-19 00:00:00 is already populated
# 2020-03-20 00:00:00 is already populated
# 2020-03-21 00:00:00 is already populated
# 2020-03-22 00:00:00 is already populated
# 2020-03-23 00:00:00 is already populated
# 2020-03-24 00:00:00 is already populated
# 2020-03-25 00:00:00 is already populated
# 2020-03-26 00:00:00 is already populated
# 2020-03-27 00:00:00 is already populated
# 2020-03-28 00:00:00 is already populated
# 2020-03-29 00:00:00 is already populated
# 2020-03-30 00:00:00 is already populated
# 2020-03-31 00:00:00 is already populated
# 2020-04-01 00:00:00 is already populated
# 2020-04-02 00:00:00 is already populated
# 2020-04-03 00:00:00 is already populated
# 2020-04-04 00:00:00 is already populated
# 2020-04-05 00:00:00 is already populated
# 2020-04-06 00:00:00 is already populated
# 2020-04-07 00:00:00 is already populated
# 2020-04-08 00:00:00 is already populated
# 2020-04-09 00:00:00 is already populated
# 2020-04-10 00:00:00 is already populated
# 2020-04-11 00:00:00 is already populated
# 2020-04-12 00:00:00 is already populated
# 2020-04-13 00:00:00 is already populated
# 2020-04-14 00:00:00 is already populated
# 2020-04-15 00:00:00 is already populated
# 2020-04-16 00:00:00 is already populated
# 2020-04-17 00:00:00 is already populated
# 2020-04-18 00:00:00 is already populated
# 2020-04-19 00:00:00 is already populated
# 2020-04-20 00:00:00 is already populated
# 2020-04-21 00:00:00 is already populated
# 2020-04-22 00:00:00 is already populated
# 2020-04-23 00:00:00 is already populated
# 2020-04-24 00:00:00 is already populated
# 2020-04-25 00:00:00 is already populated
# 2020-04-26 00:00:00 is already populated
# 2020-04-27 00:00:00 is already populated
# 2020-04-28 00:00:00 is already populated
# 2020-04-29 00:00:00 is already populated
# 2020-04-30 00:00:00 is already populated
# 2020-05-01 00:00:00 is already populated
# 2020-05-02 00:00:00 is already populated
# 2020-05-03 00:00:00 is already populated
# 2020-05-04 00:00:00 is already populated
# 2020-05-05 00:00:00 is already populated
# 2020-05-06 00:00:00 is already populated
# 2020-05-07 00:00:00 is already populated
# 2020-05-08 00:00:00 is already populated
# 2020-05-09 00:00:00 is already populated
# 2020-05-10 00:00:00 is already populated
# 2020-05-11 00:00:00 is already populated
# 2020-05-12 00:00:00 is already populated
# 2020-05-13 00:00:00 is already populated
# 2020-05-14 00:00:00 is already populated
# 2020-05-15 00:00:00 is already populated
# 2020-05-16 00:00:00 is already populated
# 2020-05-17 00:00:00 is already populated
# 2020-05-18 00:00:00 is already populated
# 2020-05-19 00:00:00 is already populated
# 2020-05-20 00:00:00 is already populated
# 2020-05-21 00:00:00 is already populated
# 2020-05-22 00:00:00 is already populated
# 2020-05-23 00:00:00 is already populated
# 2020-05-24 00:00:00 is already populated
# 2020-05-25 00:00:00 is already populated
# 2020-05-26 00:00:00 is already populated
# 2020-05-27 00:00:00 is already populated
# 2020-05-28 00:00:00 is already populated
# 2020-05-29 00:00:00 is already populated
# 2020-05-30 00:00:00 is already populated
# 2020-05-31 00:00:00 is already populated
# 2020-06-01 00:00:00 is already populated
# 2020-06-02 00:00:00 is already populated
# 2020-06-03 00:00:00 is already populated
# 2020-06-04 00:00:00 is already populated
# 2020-06-05 00:00:00 is already populated
# 2020-06-06 00:00:00 is already populated
# 2020-06-07 00:00:00 is already populated
# 2020-06-08 00:00:00 is already populated
# 2020-06-09 00:00:00 is already populated
# 2020-06-10 00:00:00 is already populated
# 2020-06-11 00:00:00 is already populated
# 2020-06-12 00:00:00 is already populated
# 2020-06-13 00:00:00 is already populated
# 2020-06-14 00:00:00 is already populated
# 2020-06-15 00:00:00 is already populated
# 2020-06-16 00:00:00 is already populated
# 2020-06-17 00:00:00 is already populated
# 2020-06-18 00:00:00 is already populated
# 2020-06-19 00:00:00 is already populated
# 2020-06-20 00:00:00 is already populated
# 2020-06-21 00:00:00 is already populated
# 2020-06-22 00:00:00 is already populated
# 2020-06-23 00:00:00 is already populated
# 2020-06-24 00:00:00 is already populated
# 2020-06-25 00:00:00 is already populated
# 2020-06-26 00:00:00 is already populated
# 2020-06-27 00:00:00 is already populated
# 2020-06-28 00:00:00 is already populated
# 2020-06-29 00:00:00 is already populated
# 2020-06-30 00:00:00 is already populated
# 2020-07-01 00:00:00 is already populated
# 2020-07-02 00:00:00 is already populated
# 2020-07-03 00:00:00 is already populated
# 2020-07-04 00:00:00 is already populated
# 2020-07-05 00:00:00 is already populated
# 2020-07-06 00:00:00 is already populated
# 2020-07-07 00:00:00 is already populated
# 2020-07-08 00:00:00 is already populated
# 2020-07-09 00:00:00 is already populated
# 2020-07-10 00:00:00 is already populated
# 2020-07-11 00:00:00 is already populated
# 2020-07-12 00:00:00 is already populated
# 2020-07-13 00:00:00 is already populated
# 2020-07-14 00:00:00 is already populated
# 2020-07-15 00:00:00 is already populated
# 2020-07-16 00:00:00 is already populated
# 2020-07-17 00:00:00 is already populated
# 2020-07-18 00:00:00 is already populated
# 2020-07-19 00:00:00 is already populated
# 2020-07-20 00:00:00 is already populated
# 2020-07-21 00:00:00 is already populated
# 2020-07-22 00:00:00 is already populated
# 2020-07-23 00:00:00 is already populated
# 2020-07-24 00:00:00 is already populated
# 2020-07-25 00:00:00 is already populated
# 2020-07-26 00:00:00 is already populated
# 2020-07-27 00:00:00 is already populated
# 2020-07-28 00:00:00 is already populated
# 2020-07-29 00:00:00 is already populated
# 2020-07-30 00:00:00 is already populated
# 2020-07-31 00:00:00 is already populated
# 2020-08-01 00:00:00 is already populated
# 2020-08-02 00:00:00 is already populated
# 2020-08-03 00:00:00 is already populated
# 2020-08-04 00:00:00 is already populated
# 2020-08-05 00:00:00 is already populated
# 2020-08-06 00:00:00 is already populated
# 2020-08-07 00:00:00 is already populated
# 2020-08-08 00:00:00 is already populated
# 2020-08-09 00:00:00 is already populated
# 2020-08-10 00:00:00 is already populated
# 2020-08-11 00:00:00 is already populated
# 2020-08-12 00:00:00 is already populated
# 2020-08-13 00:00:00 is already populated
# 2020-08-14 00:00:00 is already populated
# 2020-08-15 00:00:00 is already populated
# 2020-08-16 00:00:00 is already populated
# 2020-08-17 00:00:00 is already populated
# 2020-08-18 00:00:00 is already populated
# 2020-08-19 00:00:00 is already populated
# 2020-08-20 00:00:00 is already populated
# 2020-08-21 00:00:00 is already populated
# 2020-08-22 00:00:00 is already populated
# 2020-08-23 00:00:00 is already populated
# 2020-08-24 00:00:00 is already populated
# 2020-08-25 00:00:00 is already populated
# 2020-08-26 00:00:00 is already populated
# 2020-08-27 00:00:00 is already populated
# 2020-08-28 00:00:00 is already populated
# 2020-08-29 00:00:00 is already populated
# 2020-08-30 00:00:00 is already populated
# 2020-08-31 00:00:00 is already populated
# 2020-09-01 00:00:00 is already populated
# 2020-09-02 00:00:00 is already populated
# 2020-09-03 00:00:00 is already populated
# 2020-09-04 00:00:00 is already populated
# 2020-09-05 00:00:00 is already populated
# 2020-09-06 00:00:00 is already populated
# 2020-09-07 00:00:00 is already populated
# 2020-09-08 00:00:00 is already populated
# 2020-09-09 00:00:00 is already populated
# 2020-09-10 00:00:00 is already populated
# 2020-09-11 00:00:00 is already populated
# 2020-09-12 00:00:00 is already populated
# 2020-09-13 00:00:00 is already populated
# 2020-09-14 00:00:00 is already populated
# 2020-09-15 00:00:00 is already populated
# 2020-09-16 00:00:00 is already populated
# 2020-09-17 00:00:00 is already populated
# 2020-09-18 00:00:00 is already populated
# 2020-09-19 00:00:00 is already populated
# 2020-09-20 00:00:00 is already populated
# 2020-09-21 00:00:00 is already populated
# 2020-09-22 00:00:00 is already populated
# 2020-09-23 00:00:00 is already populated
# 2020-09-24 00:00:00 is already populated
# 2020-09-25 00:00:00 is already populated
# 2020-09-26 00:00:00 is already populated
# 2020-09-27 00:00:00 is already populated
# 2020-09-28 00:00:00 is already populated
# 2020-09-29 00:00:00 is already populated
# 2020-09-30 00:00:00 is already populated
# 2020-10-01 00:00:00 is already populated
# 2020-10-02 00:00:00 is already populated
# 2020-10-03 00:00:00 is already populated
# 2020-10-04 00:00:00 is already populated
# 2020-10-05 00:00:00 is already populated
# 2020-10-06 00:00:00 is already populated
# 2020-10-07 00:00:00 is already populated
# 2020-10-08 00:00:00 is already populated
# 2020-10-09 00:00:00 is already populated
# 2020-10-10 00:00:00 is already populated
# 2020-10-11 00:00:00 is already populated
# 2020-10-12 00:00:00 is already populated
# 2020-10-13 00:00:00 is already populated
# 2020-10-14 00:00:00 is already populated
# 2020-10-15 00:00:00 is already populated
# 2020-10-16 00:00:00 is already populated
# 2020-10-17 00:00:00 is already populated
# 2020-10-18 00:00:00 is already populated
# 2020-10-19 00:00:00 is already populated
# 2020-10-20 00:00:00 is already populated
# 2020-10-21 00:00:00 is already populated
# 2020-10-22 00:00:00 is already populated
# 2020-10-23 00:00:00 is already populated
# 2020-10-24 00:00:00 is already populated
# 2020-10-25 00:00:00 is already populated
# 2020-10-26 00:00:00 is already populated
# 2020-10-27 00:00:00 is already populated
# 2020-10-28 00:00:00 is already populated
# 2020-10-29 00:00:00 is already populated
# 2020-10-30 00:00:00 is already populated
# 2020-10-31 00:00:00 is already populated
# 2020-11-01 00:00:00 is already populated
# 2020-11-02 00:00:00 is already populated
# 2020-11-03 00:00:00 is already populated
# 2020-11-04 00:00:00 is already populated
# 2020-11-05 00:00:00 is already populated
# 2020-11-06 00:00:00 is already populated
# 2020-11-07 00:00:00 is already populated
# 2020-11-08 00:00:00 is already populated
# 2020-11-09 00:00:00 is already populated
# 2020-11-10 00:00:00 is already populated
# 2020-11-11 00:00:00 is already populated
# 2020-11-12 00:00:00 is already populated
# 2020-11-13 00:00:00 is already populated
# 2020-11-14 00:00:00 is already populated
# 2020-11-15 00:00:00 is already populated
# 2020-11-16 00:00:00 is already populated
# 2020-11-17 00:00:00 is already populated
# 2020-11-18 00:00:00 is already populated
# 2020-11-19 00:00:00 is already populated
# 2020-11-20 00:00:00 is already populated
# 2020-11-21 00:00:00 is already populated
# 2020-11-22 00:00:00 is already populated
# 2020-11-23 00:00:00 is already populated
# 2020-11-24 00:00:00 is already populated
# 2020-11-25 00:00:00 is already populated
# 2020-11-26 00:00:00 is already populated
# 2020-11-27 00:00:00 is already populated
# 2020-11-28 00:00:00 is already populated
# 2020-11-29 00:00:00 is already populated
# 2020-11-30 00:00:00 is already populated
# 2020-12-01 00:00:00 is already populated
# 2020-12-02 00:00:00 is already populated
# 2020-12-03 00:00:00 is already populated
# 2020-12-04 00:00:00 is already populated
# 2020-12-05 00:00:00 is already populated
# 2020-12-06 00:00:00 is already populated
# 2020-12-07 00:00:00 is already populated
# 2020-12-08 00:00:00 is already populated
# 2020-12-09 00:00:00 is already populated
# 2020-12-10 00:00:00 is already populated
# 2020-12-11 00:00:00 is already populated
# 2020-12-12 00:00:00 is already populated
# 2020-12-13 00:00:00 is already populated
# 2020-12-14 00:00:00 is already populated
# 2020-12-15 00:00:00 is already populated
# 2020-12-16 00:00:00 is already populated
# 2020-12-17 00:00:00 is already populated
# 2020-12-18 00:00:00 is already populated
# 2020-12-19 00:00:00 is already populated
# 2020-12-20 00:00:00 is already populated
# 2020-12-21 00:00:00 is already populated
# 2020-12-22 00:00:00 is already populated
# 2020-12-23 00:00:00 is already populated
# 2020-12-24 00:00:00 is already populated
# 2020-12-25 00:00:00 is already populated
# 2020-12-26 00:00:00 is already populated
# 2020-12-27 00:00:00 is already populated
# 2020-12-28 00:00:00 is already populated
# 2020-12-29 00:00:00 is already populated
# 2020-12-30 00:00:00 is already populated
# 2020-12-31 00:00:00 is already populated
# 2021-01-01 00:00:00 is already populated
# 2021-01-02 00:00:00 is already populated
# 2021-01-03 00:00:00 is already populated
# 2021-01-04 00:00:00 is already populated
# 2021-01-05 00:00:00 is already populated
# 2021-01-06 00:00:00 is already populated
# 2021-01-07 00:00:00 is already populated
# 2021-01-08 00:00:00 is already populated
# 2021-01-09 00:00:00 is already populated
# 2021-01-10 00:00:00 is already populated
# 2021-01-11 00:00:00 is already populated
# 2021-01-12 00:00:00 is already populated
# 2021-01-13 00:00:00 is already populated
# 2021-01-14 00:00:00 is already populated
# 2021-01-15 00:00:00 is already populated
# 2021-01-16 00:00:00 is already populated
# 2021-01-17 00:00:00 is already populated
# 2021-01-18 00:00:00 is already populated
# 2021-01-19 00:00:00 is already populated
# 2021-01-20 00:00:00 is already populated
# 2021-01-21 00:00:00 is already populated
# 2021-01-22 00:00:00 is already populated
# 2021-01-23 00:00:00 is already populated
# 2021-01-24 00:00:00 is already populated
# 2021-01-25 00:00:00 is already populated
# 2021-01-26 00:00:00 is already populated
# 2021-01-27 00:00:00 is already populated
# 2021-01-28 00:00:00 is already populated
# 2021-01-29 00:00:00 is already populated
# 2021-01-30 00:00:00 is already populated
# 2021-01-31 00:00:00 is already populated
# 2021-02-01 00:00:00 is already populated
# 2021-02-02 00:00:00 is already populated
# 2021-02-03 00:00:00 is already populated
# 2021-02-04 00:00:00 is already populated
# 2021-02-05 00:00:00 is already populated
# 2021-02-06 00:00:00 is already populated
# 2021-02-07 00:00:00 is already populated
# 2021-02-08 00:00:00 is already populated
# 2021-02-09 00:00:00 is already populated
# 2021-02-10 00:00:00 is already populated
# 2021-02-11 00:00:00 is already populated
# 2021-02-12 00:00:00 is already populated
# 2021-02-13 00:00:00 is already populated
# 2021-02-14 00:00:00 is already populated
# 2021-02-15 00:00:00 is already populated
# 2021-02-16 00:00:00 is already populated
# 2021-02-17 00:00:00 is already populated
# 2021-02-18 00:00:00 is already populated
# 2021-02-19 00:00:00 is already populated
# 2021-02-20 00:00:00 is already populated
# 2021-02-21 00:00:00 is already populated
# 2021-02-22 00:00:00 is already populated
# 2021-02-23 00:00:00 is already populated
# 2021-02-24 00:00:00 is already populated
# 2021-02-25 00:00:00 is already populated
# 2021-02-26 00:00:00 is already populated
# 2021-02-27 00:00:00 is already populated
# 2021-02-28 00:00:00 is already populated
# 2021-03-01 00:00:00 is already populated
# 2021-03-02 00:00:00 is already populated
# 2021-03-03 00:00:00 is already populated
# 2021-03-04 00:00:00 is already populated
# 2021-03-05 00:00:00 is already populated
# 2021-03-06 00:00:00 is already populated
# 2021-03-07 00:00:00 is already populated
# 2021-03-08 00:00:00 is already populated
# 2021-03-09 00:00:00 is already populated
# 2021-03-10 00:00:00 is already populated
# 2021-03-11 00:00:00 is already populated
# 2021-03-12 00:00:00 is already populated
# 2021-03-13 00:00:00 is already populated
# 2021-03-14 00:00:00 is already populated
# 2021-03-15 00:00:00 is already populated
# 2021-03-16 00:00:00 is already populated
# 2021-03-17 00:00:00 is already populated
# 2021-03-18 00:00:00 is already populated
# 2021-03-19 00:00:00 is already populated
# 2021-03-20 00:00:00 is already populated
# 2021-03-21 00:00:00 is already populated
# 2021-03-22 00:00:00 is already populated
# 2021-03-23 00:00:00 is already populated
# 2021-03-24 00:00:00 is already populated
# 2021-03-25 00:00:00 is already populated
# 2021-03-26 00:00:00 is already populated
# 2021-03-27 00:00:00 is already populated
# 2021-03-28 00:00:00 is already populated
# 2021-03-29 00:00:00 is already populated
# 2021-03-30 00:00:00 is already populated
# 2021-03-31 00:00:00 is already populated
# 2021-04-01 00:00:00 is already populated
# 2021-04-02 00:00:00 is already populated
# 2021-04-03 00:00:00 is already populated
# 2021-04-04 00:00:00 is already populated
# 2021-04-05 00:00:00 is already populated
# 2021-04-06 00:00:00 is already populated
# 2021-04-07 00:00:00 is already populated
# 2021-04-08 00:00:00 is already populated
# 2021-04-09 00:00:00 is already populated
# 2021-04-10 00:00:00 is already populated
# 2021-04-11 00:00:00 is already populated
# 2021-04-12 00:00:00 is already populated
# 2021-04-13 00:00:00 is already populated
# 2021-04-14 00:00:00 is already populated
# 2021-04-15 00:00:00 is already populated
# 2021-04-16 00:00:00 is already populated
# 2021-04-17 00:00:00 is already populated
# 2021-04-18 00:00:00 is already populated
# 2021-04-19 00:00:00 is already populated
# 2021-04-20 00:00:00 is already populated
# 2021-04-21 00:00:00 is already populated
# 2021-04-22 00:00:00 is already populated
# 2021-04-23 00:00:00 is already populated
# 2021-04-24 00:00:00 is already populated
# 2021-04-25 00:00:00 is already populated
# 2021-04-26 00:00:00 is already populated
# 2021-04-27 00:00:00 is already populated
# 2021-04-28 00:00:00 is already populated
# 2021-04-29 00:00:00 is already populated
# 2021-04-30 00:00:00 is already populated
# 2021-05-01 00:00:00 is already populated
# 2021-05-02 00:00:00 is already populated
# 2021-05-03 00:00:00 is already populated
# 2021-05-04 00:00:00 is already populated
# 2021-05-05 00:00:00 is already populated
# 2021-05-06 00:00:00 is already populated
# 2021-05-07 00:00:00 is already populated
# 2021-05-08 00:00:00 is already populated
# 2021-05-09 00:00:00 is already populated
# 2021-05-10 00:00:00 is already populated
# 2021-05-11 00:00:00 is already populated
# 2021-05-12 00:00:00 is already populated
# 2021-05-13 00:00:00 is already populated
# 2021-05-14 00:00:00 is already populated
# 2021-05-15 00:00:00 is already populated
# 2021-05-16 00:00:00 is already populated
# 2021-05-17 00:00:00 is already populated
# 2021-05-18 00:00:00 is already populated
# 2021-05-19 00:00:00 is already populated
# 2021-05-20 00:00:00 is already populated
# 2021-05-21 00:00:00 is already populated
# 2021-05-22 00:00:00 is already populated
# 2021-05-23 00:00:00 is already populated
# 2021-05-24 00:00:00 is already populated
# 2021-05-25 00:00:00 is already populated
# 2021-05-26 00:00:00 is already populated
# 2021-05-27 00:00:00 is already populated
# 2021-05-28 00:00:00 is already populated
# 2021-05-29 00:00:00 is already populated
# 2021-05-30 00:00:00 is already populated
# 2021-05-31 00:00:00 is already populated
# 2021-06-01 00:00:00 is already populated
# 2021-06-02 00:00:00 is already populated
# 2021-06-03 00:00:00 is already populated
# 2021-06-04 00:00:00 is already populated
# 2021-06-05 00:00:00 is already populated
# 2021-06-06 00:00:00 is already populated
# 2021-06-07 00:00:00 is already populated
# 2021-06-08 00:00:00 is already populated
# 2021-06-09 00:00:00 is already populated
# 2021-06-10 00:00:00 is already populated
# 2021-06-11 00:00:00 is already populated
# 2021-06-12 00:00:00 is already populated
# 2021-06-13 00:00:00 is already populated
# 2021-06-14 00:00:00 is already populated
# 2021-06-15 00:00:00 is already populated
# 2021-06-16 00:00:00 is already populated
# 2021-06-17 00:00:00 is already populated
# 2021-06-18 00:00:00 is already populated
# 2021-06-19 00:00:00 is already populated
# 2021-06-20 00:00:00 is already populated
# 2021-06-21 00:00:00 is already populated
# 2021-06-22 00:00:00 is already populated
# 2021-06-23 00:00:00 is already populated
# 2021-06-24 00:00:00 is already populated
# 2021-06-25 00:00:00 is already populated
# 2021-06-26 00:00:00 is already populated
# 2021-06-27 00:00:00 is already populated
# 2021-06-28 00:00:00 is already populated
# 2021-06-29 00:00:00 is already populated
# 2021-06-30 00:00:00 is already populated
# 2021-07-01 00:00:00 is already populated
# 2021-07-02 00:00:00 is already populated
# 2021-07-03 00:00:00 is already populated
# 2021-07-04 00:00:00 is already populated
# 2021-07-05 00:00:00 is already populated
# 2021-07-06 00:00:00 is already populated
# 2021-07-07 00:00:00 is already populated
# 2021-07-08 00:00:00 is already populated
# 2021-07-09 00:00:00 is already populated
# 2021-07-10 00:00:00 is already populated
# 2021-07-11 00:00:00 is already populated
# 2021-07-12 00:00:00 is already populated
# 2021-07-13 00:00:00 is already populated
# 2021-07-14 00:00:00 is already populated
# 2021-07-15 00:00:00 is already populated
# 2021-07-16 00:00:00 is already populated
# 2021-07-17 00:00:00 is already populated
# 2021-07-18 00:00:00 is already populated
# 2021-07-19 00:00:00 is already populated
# 2021-07-20 00:00:00 is already populated
# 2021-07-21 00:00:00 is already populated
# 2021-07-22 00:00:00 is already populated
# 2021-07-23 00:00:00 is already populated
# 2021-07-24 00:00:00 is already populated
# 2021-07-25 00:00:00 is already populated
# 2021-07-26 00:00:00 is already populated
# 2021-07-27 00:00:00 is already populated
# 2021-07-28 00:00:00 is already populated
# 2021-07-29 00:00:00 is already populated
# 2021-07-30 00:00:00 is already populated
# 2021-07-31 00:00:00 is already populated
# 2021-08-01 00:00:00 is already populated
# 2021-08-02 00:00:00 is already populated
# 2021-08-03 00:00:00 is already populated
# 2021-08-04 00:00:00 is already populated
# 2021-08-05 00:00:00 is already populated
# 2021-08-06 00:00:00 is already populated
# 2021-08-07 00:00:00 is already populated
# 2021-08-08 00:00:00 is already populated
# 2021-08-09 00:00:00 is already populated
# 2021-08-10 00:00:00 is already populated
# 2021-08-11 00:00:00 is already populated
# 2021-08-12 00:00:00 is already populated
# 2021-08-13 00:00:00 is already populated
# 2021-08-14 00:00:00 is already populated
# 2021-08-15 00:00:00 is already populated
# 2021-08-16 00:00:00 is already populated
# 2021-08-17 00:00:00 is already populated
# 2021-08-18 00:00:00 is already populated
# 2021-08-19 00:00:00 is already populated
# 2021-08-20 00:00:00 is already populated
# 2021-08-21 00:00:00 is already populated
# 2021-08-22 00:00:00 is already populated
# 2021-08-23 00:00:00 is already populated
# 2021-08-24 00:00:00 is already populated
# 2021-08-25 00:00:00 is already populated
# 2021-08-26 00:00:00 is already populated
# 2021-08-27 00:00:00 is already populated
# 2021-08-28 00:00:00 is already populated
# 2021-08-29 00:00:00 is already populated
# 2021-08-30 00:00:00 is already populated
# 2021-08-31 00:00:00 is already populated
# 2021-09-01 00:00:00 is already populated
# 2021-09-02 00:00:00 is already populated
# 2021-09-03 00:00:00 is already populated
# 2021-09-04 00:00:00 is already populated
# 2021-09-05 00:00:00 is already populated
# 2021-09-06 00:00:00 is already populated
# 2021-09-07 00:00:00 is already populated
# 2021-09-08 00:00:00 is already populated
# 2021-09-09 00:00:00 is already populated
# 2021-09-10 00:00:00 is already populated
# 2021-09-11 00:00:00 is already populated
# 2021-09-12 00:00:00 is already populated
# 2021-09-13 00:00:00 is already populated
# 2021-09-14 00:00:00 is already populated
# 2021-09-15 00:00:00 is already populated
# 2021-09-16 00:00:00 is already populated
# 2021-09-17 00:00:00 is already populated
# 2021-09-18 00:00:00 is already populated
# 2021-09-19 00:00:00 is already populated
# 2021-09-20 00:00:00 is already populated
# 2021-09-21 00:00:00 is already populated
# 2021-09-22 00:00:00 is already populated
# 2021-09-23 00:00:00 is already populated
# 2021-09-24 00:00:00 is already populated
# 2021-09-25 00:00:00 is already populated
# 2021-09-26 00:00:00 is already populated
# 2021-09-27 00:00:00 is already populated
# 2021-09-28 00:00:00 is already populated
# 2021-09-29 00:00:00 is already populated
# 2021-09-30 00:00:00 is already populated
# 2021-10-01 00:00:00 is already populated
# 2021-10-02 00:00:00 is already populated
# 2021-10-03 00:00:00 is already populated
# 2021-10-04 00:00:00 is already populated
# 2021-10-05 00:00:00 is already populated
# 2021-10-06 00:00:00 is already populated
# 2021-10-07 00:00:00 is already populated
# 2021-10-08 00:00:00 is already populated
# 2021-10-09 00:00:00 is already populated
# 2021-10-10 00:00:00 is already populated
# 2021-10-11 00:00:00 is already populated
# 2021-10-12 00:00:00 is already populated
# 2021-10-13 00:00:00 is already populated
# 2021-10-14 00:00:00 is already populated
# 2021-10-15 00:00:00 is already populated
# 2021-10-16 00:00:00 is already populated
# 2021-10-17 00:00:00 is already populated
# 2021-10-18 00:00:00 is already populated
# 2021-10-19 00:00:00 is already populated
# 2021-10-20 00:00:00 is already populated
# 2021-10-21 00:00:00 is already populated
# 2021-10-22 00:00:00 is already populated
# 2021-10-23 00:00:00 is already populated
# 2021-10-24 00:00:00 is already populated
# 2021-10-25 00:00:00 is already populated
# 2021-10-26 00:00:00 is already populated
# 2021-10-27 00:00:00 is already populated
# 2021-10-28 00:00:00 is already populated
# 2021-10-29 00:00:00 is already populated
# 2021-10-30 00:00:00 is already populated
# 2021-10-31 00:00:00 is already populated
# 2021-11-01 00:00:00 is already populated
# 2021-11-02 00:00:00 is already populated
# 2021-11-03 00:00:00 is already populated
# 2021-11-04 00:00:00 is already populated
# 2021-11-05 00:00:00 is already populated
# 2021-11-06 00:00:00 is already populated
# 2021-11-07 00:00:00 is already populated
# 2021-11-08 00:00:00 is already populated
# 2021-11-09 00:00:00 is already populated
# 2021-11-10 00:00:00 is already populated
# 2021-11-11 00:00:00 is already populated
# 2021-11-12 00:00:00 is already populated
# 2021-11-13 00:00:00 is already populated
# 2021-11-14 00:00:00 is already populated
# 2021-11-15 00:00:00 is already populated
# 2021-11-16 00:00:00 is already populated
# 2021-11-17 00:00:00 is already populated
# 2021-11-18 00:00:00 is already populated
# 2021-11-19 00:00:00 is already populated
# 2021-11-20 00:00:00 is already populated
# 2021-11-21 00:00:00 is already populated
# 2021-11-22 00:00:00 is already populated
# 2021-11-23 00:00:00 is already populated
# 2021-11-24 00:00:00 is already populated
# 2021-11-25 00:00:00 is already populated
# 2021-11-26 00:00:00 is already populated
# 2021-11-27 00:00:00 is already populated
# 2021-11-28 00:00:00 is already populated
# 2021-11-29 00:00:00 is already populated
# 2021-11-30 00:00:00 is already populated
# 2021-12-01 00:00:00 is already populated
# 2021-12-02 00:00:00 is already populated
# 2021-12-03 00:00:00 is already populated
# 2021-12-04 00:00:00 is already populated
# 2021-12-05 00:00:00 is already populated
# 2021-12-06 00:00:00 is already populated
# 2021-12-07 00:00:00 is already populated
# 2021-12-08 00:00:00 is already populated
# 2021-12-09 00:00:00 is already populated
# 2021-12-10 00:00:00 is already populated
# 2021-12-11 00:00:00 is already populated
# 2021-12-12 00:00:00 is already populated
# 2021-12-13 00:00:00 is already populated
# 2021-12-14 00:00:00 is already populated
# 2021-12-15 00:00:00 is already populated
# 2021-12-16 00:00:00 is already populated
# 2021-12-17 00:00:00 is already populated
# 2021-12-18 00:00:00 is already populated
# 2021-12-19 00:00:00 is already populated
# 2021-12-20 00:00:00 is already populated
# 2021-12-21 00:00:00 is already populated
# 2021-12-22 00:00:00 is already populated
# 2021-12-23 00:00:00 is already populated
# 2021-12-24 00:00:00 is already populated
# 2021-12-25 00:00:00 is already populated
# 2021-12-26 00:00:00 is already populated
# 2021-12-27 00:00:00 is already populated
# 2021-12-28 00:00:00 is already populated
# 2021-12-29 00:00:00 is already populated
# 2021-12-30 00:00:00 is already populated
# 2021-12-31 00:00:00 is already populated
# 2022-01-01 00:00:00 is already populated
# 2022-01-02 00:00:00 is already populated
# 2022-01-03 00:00:00 is already populated
# 2022-01-04 00:00:00 is already populated
# 2022-01-05 00:00:00 is already populated
# 2022-01-06 00:00:00 is already populated
# 2022-01-07 00:00:00 is already populated
# 2022-01-08 00:00:00 is already populated
# 2022-01-09 00:00:00 is already populated
# 2022-01-10 00:00:00 is already populated
# 2022-01-11 00:00:00 is already populated
# 2022-01-12 00:00:00 is already populated
# 2022-01-13 00:00:00 is already populated
# 2022-01-14 00:00:00 is already populated
# 2022-01-15 00:00:00 is already populated
# 2022-01-16 00:00:00 is already populated
# 2022-01-17 00:00:00 is already populated
# 2022-01-18 00:00:00 is already populated
# 2022-01-19 00:00:00 is already populated
# 2022-01-20 00:00:00 is already populated
# 2022-01-21 00:00:00 is already populated
# 2022-01-22 00:00:00 is already populated
# 2022-01-23 00:00:00 is already populated
# 2022-01-24 00:00:00 is already populated
# 2022-01-25 00:00:00 is already populated
# 2022-01-26 00:00:00 is already populated
# 2022-01-27 00:00:00 is already populated
# 2022-01-28 00:00:00 is already populated
# 2022-01-29 00:00:00 is already populated
# 2022-01-30 00:00:00 is already populated
# 2022-01-31 00:00:00 is already populated
# 2022-02-01 00:00:00 is already populated
# 2022-02-02 00:00:00 is already populated
# 2022-02-03 00:00:00 is already populated
# 2022-02-04 00:00:00 is already populated
# 2022-02-05 00:00:00 is already populated
# 2022-02-06 00:00:00 is already populated
# 2022-02-07 00:00:00 is already populated
# 2022-02-08 00:00:00 is already populated
# 2022-02-09 00:00:00 is already populated
# 2022-02-10 00:00:00 is already populated
# 2022-02-11 00:00:00 is already populated
# 2022-02-12 00:00:00 is already populated
# 2022-02-13 00:00:00 is already populated
# 2022-02-14 00:00:00 is already populated
# 2022-02-15 00:00:00 is already populated
# 2022-02-16 00:00:00 is already populated
# 2022-02-17 00:00:00 is already populated
# 2022-02-18 00:00:00 is already populated
# 2022-02-19 00:00:00 is already populated
# 2022-02-20 00:00:00 is already populated
# 2022-02-21 00:00:00 is already populated
# 2022-02-22 00:00:00 is already populated
# 2022-02-23 00:00:00 is already populated
# 2022-02-24 00:00:00 is already populated
# 2022-02-25 00:00:00 is already populated
# 2022-02-26 00:00:00 is already populated
# 2022-02-27 00:00:00 is already populated
# 2022-02-28 00:00:00 is already populated
# 2022-03-01 00:00:00 is already populated
# 2022-03-02 00:00:00 is already populated
# 2022-03-03 00:00:00 is already populated
# 2022-03-04 00:00:00 is already populated
# 2022-03-05 00:00:00 is already populated
# 2022-03-06 00:00:00 is already populated
# 2022-03-07 00:00:00 is already populated
# 2022-03-08 00:00:00 is already populated
# 2022-03-09 00:00:00 is already populated
# 2022-03-10 00:00:00 is already populated
# 2022-03-11 00:00:00 is already populated
# 2022-03-12 00:00:00 is already populated
# 2022-03-13 00:00:00 is already populated
# 2022-03-14 00:00:00 is already populated
# 2022-03-15 00:00:00 is already populated
# 2022-03-16 00:00:00 is already populated
# 2022-03-17 00:00:00 is already populated
# 2022-03-18 00:00:00 is already populated
# 2022-03-19 00:00:00 is already populated
# 2022-03-20 00:00:00 is already populated
# 2022-03-21 00:00:00 is already populated
# 2022-03-22 00:00:00 is already populated
# 2022-03-23 00:00:00 is already populated
# 2022-03-24 00:00:00 is already populated
# 2022-03-25 00:00:00 is already populated
# 2022-03-26 00:00:00 is already populated
# 2022-03-27 00:00:00 is already populated
# 2022-03-28 00:00:00 is already populated
# 2022-03-29 00:00:00 is already populated
# 2022-03-30 00:00:00 is already populated
# 2022-03-31 00:00:00 is already populated
# 2022-04-01 00:00:00 is already populated
# 2022-04-02 00:00:00 is already populated
# 2022-04-03 00:00:00 is already populated
# 2022-04-04 00:00:00 is already populated
# 2022-04-05 00:00:00 is already populated
# 2022-04-06 00:00:00 is already populated
# 2022-04-07 00:00:00 is already populated
# 2022-04-08 00:00:00 is already populated
# 2022-04-09 00:00:00 is already populated
# 2022-04-10 00:00:00 is already populated
# 2022-04-11 00:00:00 is already populated
# 2022-04-12 00:00:00 is already populated
# 2022-04-13 00:00:00 is already populated
# 2022-04-14 00:00:00 is already populated
# 2022-04-15 00:00:00 is already populated
# 2022-04-16 00:00:00 is already populated
# 2022-04-17 00:00:00 is already populated
# 2022-04-18 00:00:00 is already populated
# 2022-04-19 00:00:00 is already populated
# 2022-04-20 00:00:00 is already populated
# 2022-04-21 00:00:00 is already populated
# 2022-04-22 00:00:00 is already populated
# 2022-04-23 00:00:00 is already populated
# 2022-04-24 00:00:00 is already populated
# 2022-04-25 00:00:00 is already populated
# 2022-04-26 00:00:00 is already populated
# 2022-04-27 00:00:00 is already populated
# 2022-04-28 00:00:00 is already populated
# 2022-04-29 00:00:00 is already populated
# 2022-04-30 00:00:00 is already populated
# 2022-05-01 00:00:00 is already populated
# 2022-05-02 00:00:00 is already populated
# 2022-05-03 00:00:00 is already populated
# 2022-05-04 00:00:00 is already populated
# 2022-05-05 00:00:00 is already populated
# 2022-05-06 00:00:00 is already populated
# 2022-05-07 00:00:00 is already populated
# 2022-05-08 00:00:00 is already populated
# 2022-05-09 00:00:00 is already populated
# 2022-05-10 00:00:00 is already populated
# 2022-05-11 00:00:00 is already populated
# 2022-05-12 00:00:00 is already populated
# 2022-05-13 00:00:00 is already populated
# 2022-05-14 00:00:00 is already populated
# 2022-05-15 00:00:00 is already populated
# 2022-05-16 00:00:00 is already populated
# 2022-05-17 00:00:00 is already populated
# 2022-05-18 00:00:00 is already populated
# 2022-05-19 00:00:00 is already populated
# 2022-05-20 00:00:00 is already populated
# 2022-05-21 00:00:00 is already populated
# 2022-05-22 00:00:00 is already populated
# 2022-05-23 00:00:00 is already populated
# 2022-05-24 00:00:00 is already populated
# 2022-05-25 00:00:00 is already populated
# 2022-05-26 00:00:00 is already populated
# 2022-05-27 00:00:00 is already populated
# 2022-05-28 00:00:00 is already populated
# 2022-05-29 00:00:00 is already populated
# 2022-05-30 00:00:00 is already populated
# 2022-05-31 00:00:00 is already populated
# 2022-06-01 00:00:00 is already populated
# 2022-06-02 00:00:00 is already populated
# 2022-06-03 00:00:00 is already populated
# 2022-06-04 00:00:00 is already populated
# 2022-06-05 00:00:00 is already populated
# 2022-06-06 00:00:00 is already populated
# 2022-06-07 00:00:00 is already populated
# 2022-06-08 00:00:00 is already populated
# 2022-06-09 00:00:00 is already populated
# 2022-06-10 00:00:00 is already populated
# 2022-06-11 00:00:00 is already populated
# 2022-06-12 00:00:00 is already populated
# 2022-06-13 00:00:00 is already populated
# 2022-06-14 00:00:00 is already populated
# 2022-06-15 00:00:00 is already populated
# 2022-06-16 00:00:00 is already populated
# 2022-06-17 00:00:00 is already populated
# 2022-06-18 00:00:00 is already populated
# 2022-06-19 00:00:00 is already populated
# 2022-06-20 00:00:00 is already populated
# 2022-06-21 00:00:00 is already populated
# 2022-06-22 00:00:00 is already populated
# 2022-06-23 00:00:00 is already populated
# 2022-06-24 00:00:00 is already populated
# 2022-06-25 00:00:00 is already populated
# 2022-06-26 00:00:00 is already populated
# 2022-06-27 00:00:00 is already populated
# 2022-06-28 00:00:00 is already populated
# 2022-06-29 00:00:00 is already populated
# 2022-06-30 00:00:00 is already populated
# 2022-07-01 00:00:00 is already populated
# 2022-07-02 00:00:00 is already populated
# 2022-07-03 00:00:00 is already populated
# 2022-07-04 00:00:00 is already populated
# 2022-07-05 00:00:00 is already populated
# 2022-07-06 00:00:00 is already populated
# 2022-07-07 00:00:00 is already populated
# 2022-07-08 00:00:00 is already populated
# 2022-07-09 00:00:00 is already populated
# 2022-07-10 00:00:00 is already populated
# 2022-07-11 00:00:00 is already populated
# 2022-07-12 00:00:00 is already populated
# 2022-07-13 00:00:00 is already populated
# 2022-07-14 00:00:00 is already populated
# 2022-07-15 00:00:00 is already populated
# 2022-07-16 00:00:00 is already populated
# 2022-07-17 00:00:00 is already populated
# 2022-07-18 00:00:00 is already populated
# 2022-07-19 00:00:00 is already populated
# 2022-07-20 00:00:00 is already populated
# 2022-07-21 00:00:00 is already populated
# 2022-07-22 00:00:00 is already populated
# 2022-07-23 00:00:00 is already populated
# 2022-07-24 00:00:00 is already populated
# 2022-07-25 00:00:00 is already populated
# 2022-07-26 00:00:00 is already populated
# 2022-07-27 00:00:00 is already populated
# 2022-07-28 00:00:00 is already populated
# 2022-07-29 00:00:00 is already populated
# 2022-07-30 00:00:00 is already populated
# 2022-07-31 00:00:00 is already populated
# 2022-08-01 00:00:00 is already populated
# 2022-08-02 00:00:00 is already populated
# 2022-08-03 00:00:00 is already populated
# 2022-08-04 00:00:00 is already populated
# 2022-08-05 00:00:00 is already populated
# 2022-08-06 00:00:00 is already populated
# 2022-08-07 00:00:00 is already populated
# 2022-08-08 00:00:00 is already populated
# 2022-08-09 00:00:00 is already populated
# 2022-08-10 00:00:00 is already populated
# 2022-08-11 00:00:00 is already populated
# 2022-08-12 00:00:00 is already populated
# 2022-08-13 00:00:00 is already populated
# 2022-08-14 00:00:00 is already populated
# 2022-08-15 00:00:00 is already populated
# 2022-08-16 00:00:00 is already populated
# 2022-08-17 00:00:00 is already populated
# 2022-08-18 00:00:00 is already populated
# 2022-08-19 00:00:00 is already populated
# 2022-08-20 00:00:00 is already populated
# 2022-08-21 00:00:00 is already populated
# 2022-08-22 00:00:00 is already populated
# 2022-08-23 00:00:00 is already populated
# 2022-08-24 00:00:00 is already populated
# 2022-08-25 00:00:00 is already populated
# 2022-08-26 00:00:00 is already populated
# 2022-08-27 00:00:00 is already populated
# 2022-08-28 00:00:00 is already populated
# 2022-08-29 00:00:00 is already populated
# 2022-08-30 00:00:00 is already populated
# 2022-08-31 00:00:00 is already populated
# 2022-09-01 00:00:00 is already populated
# 2022-09-02 00:00:00 is already populated
# 2022-09-03 00:00:00 is already populated
# 2022-09-04 00:00:00 is already populated
# 2022-09-05 00:00:00 is already populated
# 2022-09-06 00:00:00 is already populated
# 2022-09-07 00:00:00 is already populated
# 2022-09-08 00:00:00 is already populated
# 2022-09-09 00:00:00 is already populated
# 2022-09-10 00:00:00 is already populated
# 2022-09-11 00:00:00 is already populated
# 2022-09-12 00:00:00 is already populated
# 2022-09-13 00:00:00 is already populated
# 2022-09-14 00:00:00 is already populated
# 2022-09-15 00:00:00 is already populated
# 2022-09-16 00:00:00 is already populated
# 2022-09-17 00:00:00 is already populated
# 2022-09-18 00:00:00 is already populated
# 2022-09-19 00:00:00 is already populated
# 2022-09-20 00:00:00 is already populated
# 2022-09-21 00:00:00 is already populated
# 2022-09-22 00:00:00 is already populated
# 2022-09-23 00:00:00 is already populated
# 2022-09-24 00:00:00 is already populated
# 2022-09-25 00:00:00 is already populated
# 2022-09-26 00:00:00 is already populated
# 2022-09-27 00:00:00 is already populated
# 2022-09-28 00:00:00 is already populated
# 2022-09-29 00:00:00 is already populated
# 2022-09-30 00:00:00 is already populated
# 2022-10-01 00:00:00 is already populated
# 2022-10-02 00:00:00 is already populated
# 2022-10-03 00:00:00 is already populated
# 2022-10-04 00:00:00 is already populated
# 2022-10-05 00:00:00 is already populated
# 2022-10-06 00:00:00 is already populated
# 2022-10-07 00:00:00 is already populated
# 2022-10-08 00:00:00 is already populated
# 2022-10-09 00:00:00 is already populated
# 2022-10-10 00:00:00 is already populated
# 2022-10-11 00:00:00 is already populated
# 2022-10-12 00:00:00 is already populated
# 2022-10-13 00:00:00 is already populated
# 2022-10-14 00:00:00 is already populated
# 2022-10-15 00:00:00 is already populated
# 2022-10-16 00:00:00 is already populated
# 2022-10-17 00:00:00 is already populated
# 2022-10-18 00:00:00 is already populated
# 2022-10-19 00:00:00 is already populated
# 2022-10-20 00:00:00 is already populated
# 2022-10-21 00:00:00 is already populated
# 2022-10-22 00:00:00 is already populated
# 2022-10-23 00:00:00 is already populated
# 2022-10-24 00:00:00 is already populated
# 2022-10-25 00:00:00 is already populated
# 2022-10-26 00:00:00 is already populated
# 2022-10-27 00:00:00 is already populated
# 2022-10-28 00:00:00 is already populated
# 2022-10-29 00:00:00 is already populated
# 2022-10-30 00:00:00 is already populated
# 2022-10-31 00:00:00 is already populated
# 2022-11-01 00:00:00 is already populated
# 2022-11-02 00:00:00 is already populated
# 2022-11-03 00:00:00 is already populated
# 2022-11-04 00:00:00 is already populated
# 2022-11-05 00:00:00 is already populated
# 2022-11-06 00:00:00 is already populated
# 2022-11-07 00:00:00 is already populated
# 2022-11-08 00:00:00 is already populated
# 2022-11-09 00:00:00 is already populated
# 2022-11-10 00:00:00 is already populated
# 2022-11-11 00:00:00 is already populated
# 2022-11-12 00:00:00 is already populated
# 2022-11-13 00:00:00 is already populated
# 2022-11-14 00:00:00 is already populated
# 2022-11-15 00:00:00 is already populated
# 2022-11-16 00:00:00 is already populated
# 2022-11-17 00:00:00 is already populated
# 2022-11-18 00:00:00 is already populated
# 2022-11-19 00:00:00 is already populated
# 2022-11-20 00:00:00 is already populated
# 2022-11-21 00:00:00 is already populated
# 2022-11-22 00:00:00 is already populated
# 2022-11-23 00:00:00 is already populated
# 2022-11-24 00:00:00 is already populated
# 2022-11-25 00:00:00 is already populated
# 2022-11-26 00:00:00 is already populated
# 2022-11-27 00:00:00 is already populated
# 2022-11-28 00:00:00 is already populated
# 2022-11-29 00:00:00 is already populated
# 2022-11-30 00:00:00 is already populated
# 2022-12-01 00:00:00 is already populated
# 2022-12-02 00:00:00 is already populated
# 2022-12-03 00:00:00 is already populated
# 2022-12-04 00:00:00 is already populated
# 2022-12-05 00:00:00 is already populated
# 2022-12-06 00:00:00 is already populated
# 2022-12-07 00:00:00 is already populated
# 2022-12-08 00:00:00 is already populated
# 2022-12-09 00:00:00 is already populated
# 2022-12-10 00:00:00 is already populated
# 2022-12-11 00:00:00 is already populated
# 2022-12-12 00:00:00 is already populated
# 2022-12-13 00:00:00 is already populated
# 2022-12-14 00:00:00 is already populated
# 2022-12-15 00:00:00 is already populated
# 2022-12-16 00:00:00 is already populated
# 2022-12-17 00:00:00 is already populated
# 2022-12-18 00:00:00 is already populated
# 2022-12-19 00:00:00 is already populated
# 2022-12-20 00:00:00 is already populated
# 2022-12-21 00:00:00 is already populated
# 2022-12-22 00:00:00 is already populated
# 2022-12-23 00:00:00 is already populated
# 2022-12-24 00:00:00 is already populated
# 2022-12-25 00:00:00 is already populated
# 2022-12-26 00:00:00 is already populated
# 2022-12-27 00:00:00 is already populated
# 2022-12-28 00:00:00 is already populated
# 2022-12-29 00:00:00 is already populated
# 2022-12-30 00:00:00 is already populated
# 2022-12-31 00:00:00 is already populated
# 2023-01-01 00:00:00 is already populated
# 2023-01-02 00:00:00 is already populated
# 2023-01-03 00:00:00 is already populated
# 2023-01-04 00:00:00 is already populated
# 2023-01-05 00:00:00 is already populated
# 2023-01-06 00:00:00 is already populated
# 2023-01-07 00:00:00 is already populated
# 2023-01-08 00:00:00 is already populated
# 2023-01-09 00:00:00 is already populated
# 2023-01-10 00:00:00 is already populated
# 2023-01-11 00:00:00 is already populated
# 2023-01-12 00:00:00 is already populated
# 2023-01-13 00:00:00 is already populated
# 2023-01-14 00:00:00 is already populated
# 2023-01-15 00:00:00 is already populated
# 2023-01-16 00:00:00 is already populated
# 2023-01-17 00:00:00 is already populated
# 2023-01-18 00:00:00 is already populated
# 2023-01-19 00:00:00 is already populated
# 2023-01-20 00:00:00 is already populated
# 2023-01-21 00:00:00 is already populated
# 2023-01-22 00:00:00 is already populated
# 2023-01-23 00:00:00 is already populated
# 2023-01-24 00:00:00 is already populated
# 2023-01-25 00:00:00 is already populated
# 2023-01-26 00:00:00 is already populated
# 2023-01-27 00:00:00 is already populated
# 2023-01-28 00:00:00 is already populated
# 2023-01-29 00:00:00 is already populated
# 2023-01-30 00:00:00 is already populated
# 2023-01-31 00:00:00 is already populated
# 2023-02-01 00:00:00 is already populated
# 2023-02-02 00:00:00 is already populated
# 2023-02-03 00:00:00 is already populated
# 2023-02-04 00:00:00 is already populated
# 2023-02-05 00:00:00 is already populated
# 2023-02-06 00:00:00 is already populated
# 2023-02-07 00:00:00 is already populated
# 2023-02-08 00:00:00 is already populated
# 2023-02-09 00:00:00 is already populated
# 2023-02-10 00:00:00 is already populated
# 2023-02-11 00:00:00 is already populated
# 2023-02-12 00:00:00 is already populated
# 2023-02-13 00:00:00 is already populated
# 2023-02-14 00:00:00 is already populated
# 2023-02-15 00:00:00 is already populated
# 2023-02-16 00:00:00 is already populated
# 2023-02-17 00:00:00 is already populated
# 2023-02-18 00:00:00 is already populated
# 2023-02-19 00:00:00 is already populated
# 2023-02-20 00:00:00 is already populated
# 2023-02-21 00:00:00 is already populated
# 2023-02-22 00:00:00 is already populated
# 2023-02-23 00:00:00 is already populated
# 2023-02-24 00:00:00 is already populated
# 2023-02-25 00:00:00 is already populated
# 2023-02-26 00:00:00 is already populated
# 2023-02-27 00:00:00 is already populated
# 2023-02-28 00:00:00 is already populated
# 2023-03-01 00:00:00 is already populated
# 2023-03-02 00:00:00 is already populated
# 2023-03-03 00:00:00 is already populated
# 2023-03-04 00:00:00 is already populated
# 2023-03-05 00:00:00 is already populated
# 2023-03-06 00:00:00 is already populated
# 2023-03-07 00:00:00 is already populated
# 2023-03-08 00:00:00 is already populated
# 2023-03-09 00:00:00 is already populated
# 2023-03-10 00:00:00 is already populated
# 2023-03-11 00:00:00 is already populated
# 2023-03-12 00:00:00 is already populated
# 2023-03-13 00:00:00 is already populated
# 2023-03-14 00:00:00 is already populated
# 2023-03-15 00:00:00 is already populated
# 2023-03-16 00:00:00 is already populated
# 2023-03-17 00:00:00 is already populated
# 2023-03-18 00:00:00 is already populated
# 2023-03-19 00:00:00 is already populated
# 2023-03-20 00:00:00 is already populated
# 2023-03-21 00:00:00 is already populated
# 2023-03-22 00:00:00 is already populated
# 2023-03-23 00:00:00 is already populated
# 2023-03-24 00:00:00 is already populated
# 2023-03-25 00:00:00 is already populated
# 2023-03-26 00:00:00 is already populated
# 2023-03-27 00:00:00 is already populated
# 2023-03-28 00:00:00 is already populated
# 2023-03-29 00:00:00 is already populated
# 2023-03-30 00:00:00 is already populated
# 2023-03-31 00:00:00 is already populated
# 2023-04-01 00:00:00 is already populated
# 2023-04-02 00:00:00 is already populated
# 2023-04-03 00:00:00 is already populated
# 2023-04-04 00:00:00 is already populated
# 2023-04-05 00:00:00 is already populated
# 2023-04-06 00:00:00 is already populated
# 2023-04-07 00:00:00 is already populated
# 2023-04-08 00:00:00 is already populated
# 2023-04-09 00:00:00 is already populated
# 2023-04-10 00:00:00 is already populated
# 2023-04-11 00:00:00 is already populated
# 2023-04-12 00:00:00 is already populated
# 2023-04-13 00:00:00 is already populated
# 2023-04-14 00:00:00 is already populated
# 2023-04-15 00:00:00 is already populated
# 2023-04-16 00:00:00 is already populated
# 2023-04-17 00:00:00 is already populated
# 2023-04-18 00:00:00 is already populated
# 2023-04-19 00:00:00 is already populated
# 2023-04-20 00:00:00 is already populated
# 2023-04-21 00:00:00 is already populated
# 2023-04-22 00:00:00 is already populated
# 2023-04-23 00:00:00 is already populated
# 2023-04-24 00:00:00 is already populated
# 2023-04-25 00:00:00 is already populated
# 2023-04-26 00:00:00 is already populated
# 2023-04-27 00:00:00 is already populated
# 2023-04-28 00:00:00 is already populated
# 2023-04-29 00:00:00 is already populated
# 2023-04-30 00:00:00 is already populated
# 2023-05-01 00:00:00 is already populated
# 2023-05-02 00:00:00 is already populated
# 2023-05-03 00:00:00 is already populated
# 2023-05-04 00:00:00 is already populated
# 2023-05-05 00:00:00 is already populated
# 2023-05-06 00:00:00 is already populated
# 2023-05-07 00:00:00 is already populated
# 2023-05-08 00:00:00 is already populated
# 2023-05-09 00:00:00 is already populated
# 2023-05-10 00:00:00 is already populated
# 2023-05-11 00:00:00 is already populated
# 2023-05-12 00:00:00 is already populated
# 2023-05-13 00:00:00 is already populated
# 2023-05-14 00:00:00 is already populated
# 2023-05-15 00:00:00 is already populated
# 2023-05-16 00:00:00 is already populated
# 2023-05-17 00:00:00 is already populated
# 2023-05-18 00:00:00 is already populated
# 2023-05-19 00:00:00 is already populated
# 2023-05-20 00:00:00 is already populated
# 2023-05-21 00:00:00 is already populated
# 2023-05-22 00:00:00 is already populated
# 2023-05-23 00:00:00 is already populated
# 2023-05-24 00:00:00 is already populated
# 2023-05-25 00:00:00 is already populated
# 2023-05-26 00:00:00 is already populated
# 2023-05-27 00:00:00 is already populated
# 2023-05-28 00:00:00 is already populated
# 2023-05-29 00:00:00 is already populated
# 2023-05-30 00:00:00 is already populated
# 2023-05-31 00:00:00 is already populated
# 2023-06-01 00:00:00 is already populated

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

QUERIED_TEXT = 'music'

# Prepare dataframe for all applicable date ranges for which there will be total_{QUERIED_TEXT} count
queried_start_date = pd.to_datetime('2020-01-01')
queried_end_date = pd.to_datetime('2023-06-01')
queried_date_range = pd.date_range(start=queried_start_date, end=queried_end_date)
queried_date_range_df = pd.DataFrame({'date': queried_date_range})
queried_date_range_df[f'total_{QUERIED_TEXT}'] = None

# Set the base URL
base_url = 'https://donyc.com/events/{}/{}/{}/{}?page={}'

# Verify that file exists
csv_filename = f'donyc_{QUERIED_TEXT}.csv'
if os.path.isfile(csv_filename):
    queried_date_range_df = pd.read_csv(csv_filename, parse_dates=['date'])

# Loop through each date in the date range
for i, row in queried_date_range_df.iterrows():

    continue_for = False

    date = row['date']

    # Check if the 'total_{QUERIED_TEXT}' column is not NaN, if yes then break out of the loop
    if not pd.isna(row[f'total_{QUERIED_TEXT}']):
        print(f'{date} is already populated')
        continue

    # Format the URL with the year, month, day, and page number
    year = date.year
    month = date.month
    day = date.day
    page_num = 1

    # Initialize the count to 0
    count = 0

    # Loop through each page of {QUERIED_TEXT} for the current date
    while True:

        url = base_url.format(QUERIED_TEXT, year, month, day, page_num)

        # Make a request to the current page
        response = requests.get(url)

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all div elements with a class attribute starting with 'ds-listing event-card'
        event_cards = soup.select('div[class^="ds-listing event-card"]')

        # If no event cards are found, break out of the loop
        if not event_cards:
            break

        # Loop through each event card that matches the specified classes
        for card in event_cards:
            # Find the anchor tag with an href attribute that starts with '/events/{}/{}/{}/' and the specified classes
            anchor = card.find('a', href=lambda href: href and href.startswith('/events/{}/{}/{}/'.format(year, month, day)), class_='ds-listing-event-title url summary')
            if anchor:
                count += 1
            else:
                continue_for = True
                break

        # Increment the page number and update the URL
        print(page_num)
        page_num += 1

        if continue_for:
            break

    # Set the count for the current date in the 'total_{QUERIED_TEXT}' column of the DataFrame
    queried_date_range_df.loc[i, f'total_{QUERIED_TEXT}'] = count
    queried_date_range_df.to_csv(csv_filename, index=False)
    print(queried_date_range_df.loc[i])
# Out:
# 2020-01-01 00:00:00 is already populated
# 2020-01-02 00:00:00 is already populated
# 2020-01-03 00:00:00 is already populated
# 2020-01-04 00:00:00 is already populated
# 2020-01-05 00:00:00 is already populated
# 2020-01-06 00:00:00 is already populated
# 2020-01-07 00:00:00 is already populated
# 2020-01-08 00:00:00 is already populated
# 2020-01-09 00:00:00 is already populated
# 2020-01-10 00:00:00 is already populated
# 2020-01-11 00:00:00 is already populated
# 2020-01-12 00:00:00 is already populated
# 2020-01-13 00:00:00 is already populated
# 2020-01-14 00:00:00 is already populated
# 2020-01-15 00:00:00 is already populated
# 2020-01-16 00:00:00 is already populated
# 2020-01-17 00:00:00 is already populated
# 2020-01-18 00:00:00 is already populated
# 2020-01-19 00:00:00 is already populated
# 2020-01-20 00:00:00 is already populated
# 2020-01-21 00:00:00 is already populated
# 2020-01-22 00:00:00 is already populated
# 2020-01-23 00:00:00 is already populated
# 2020-01-24 00:00:00 is already populated
# 2020-01-25 00:00:00 is already populated
# 2020-01-26 00:00:00 is already populated
# 2020-01-27 00:00:00 is already populated
# 2020-01-28 00:00:00 is already populated
# 2020-01-29 00:00:00 is already populated
# 2020-01-30 00:00:00 is already populated
# 2020-01-31 00:00:00 is already populated
# 2020-02-01 00:00:00 is already populated
# 2020-02-02 00:00:00 is already populated
# 2020-02-03 00:00:00 is already populated
# 2020-02-04 00:00:00 is already populated
# 2020-02-05 00:00:00 is already populated
# 2020-02-06 00:00:00 is already populated
# 2020-02-07 00:00:00 is already populated
# 2020-02-08 00:00:00 is already populated
# 2020-02-09 00:00:00 is already populated
# 2020-02-10 00:00:00 is already populated
# 2020-02-11 00:00:00 is already populated
# 2020-02-12 00:00:00 is already populated
# 2020-02-13 00:00:00 is already populated
# 2020-02-14 00:00:00 is already populated
# 2020-02-15 00:00:00 is already populated
# 2020-02-16 00:00:00 is already populated
# 2020-02-17 00:00:00 is already populated
# 2020-02-18 00:00:00 is already populated
# 2020-02-19 00:00:00 is already populated
# 2020-02-20 00:00:00 is already populated
# 2020-02-21 00:00:00 is already populated
# 2020-02-22 00:00:00 is already populated
# 2020-02-23 00:00:00 is already populated
# 2020-02-24 00:00:00 is already populated
# 2020-02-25 00:00:00 is already populated
# 2020-02-26 00:00:00 is already populated
# 2020-02-27 00:00:00 is already populated
# 2020-02-28 00:00:00 is already populated
# 2020-02-29 00:00:00 is already populated
# 2020-03-01 00:00:00 is already populated
# 2020-03-02 00:00:00 is already populated
# 2020-03-03 00:00:00 is already populated
# 2020-03-04 00:00:00 is already populated
# 2020-03-05 00:00:00 is already populated
# 2020-03-06 00:00:00 is already populated
# 2020-03-07 00:00:00 is already populated
# 2020-03-08 00:00:00 is already populated
# 2020-03-09 00:00:00 is already populated
# 2020-03-10 00:00:00 is already populated
# 2020-03-11 00:00:00 is already populated
# 2020-03-12 00:00:00 is already populated
# 2020-03-13 00:00:00 is already populated
# 2020-03-14 00:00:00 is already populated
# 2020-03-15 00:00:00 is already populated
# 2020-03-16 00:00:00 is already populated
# 2020-03-17 00:00:00 is already populated
# 2020-03-18 00:00:00 is already populated
# 2020-03-19 00:00:00 is already populated
# 2020-03-20 00:00:00 is already populated
# 2020-03-21 00:00:00 is already populated
# 2020-03-22 00:00:00 is already populated
# 2020-03-23 00:00:00 is already populated
# 2020-03-24 00:00:00 is already populated
# 2020-03-25 00:00:00 is already populated
# 2020-03-26 00:00:00 is already populated
# 2020-03-27 00:00:00 is already populated
# 2020-03-28 00:00:00 is already populated
# 2020-03-29 00:00:00 is already populated
# 2020-03-30 00:00:00 is already populated
# 2020-03-31 00:00:00 is already populated
# 2020-04-01 00:00:00 is already populated
# 2020-04-02 00:00:00 is already populated
# 2020-04-03 00:00:00 is already populated
# 2020-04-04 00:00:00 is already populated
# 2020-04-05 00:00:00 is already populated
# 2020-04-06 00:00:00 is already populated
# 2020-04-07 00:00:00 is already populated
# 2020-04-08 00:00:00 is already populated
# 2020-04-09 00:00:00 is already populated
# 2020-04-10 00:00:00 is already populated
# 2020-04-11 00:00:00 is already populated
# 2020-04-12 00:00:00 is already populated
# 2020-04-13 00:00:00 is already populated
# 2020-04-14 00:00:00 is already populated
# 2020-04-15 00:00:00 is already populated
# 2020-04-16 00:00:00 is already populated
# 2020-04-17 00:00:00 is already populated
# 2020-04-18 00:00:00 is already populated
# 2020-04-19 00:00:00 is already populated
# 2020-04-20 00:00:00 is already populated
# 2020-04-21 00:00:00 is already populated
# 2020-04-22 00:00:00 is already populated
# 2020-04-23 00:00:00 is already populated
# 2020-04-24 00:00:00 is already populated
# 2020-04-25 00:00:00 is already populated
# 2020-04-26 00:00:00 is already populated
# 2020-04-27 00:00:00 is already populated
# 2020-04-28 00:00:00 is already populated
# 2020-04-29 00:00:00 is already populated
# 2020-04-30 00:00:00 is already populated
# 2020-05-01 00:00:00 is already populated
# 2020-05-02 00:00:00 is already populated
# 2020-05-03 00:00:00 is already populated
# 2020-05-04 00:00:00 is already populated
# 2020-05-05 00:00:00 is already populated
# 2020-05-06 00:00:00 is already populated
# 2020-05-07 00:00:00 is already populated
# 2020-05-08 00:00:00 is already populated
# 2020-05-09 00:00:00 is already populated
# 2020-05-10 00:00:00 is already populated
# 2020-05-11 00:00:00 is already populated
# 2020-05-12 00:00:00 is already populated
# 2020-05-13 00:00:00 is already populated
# 2020-05-14 00:00:00 is already populated
# 2020-05-15 00:00:00 is already populated
# 2020-05-16 00:00:00 is already populated
# 2020-05-17 00:00:00 is already populated
# 2020-05-18 00:00:00 is already populated
# 2020-05-19 00:00:00 is already populated
# 2020-05-20 00:00:00 is already populated
# 2020-05-21 00:00:00 is already populated
# 2020-05-22 00:00:00 is already populated
# 2020-05-23 00:00:00 is already populated
# 2020-05-24 00:00:00 is already populated
# 2020-05-25 00:00:00 is already populated
# 2020-05-26 00:00:00 is already populated
# 2020-05-27 00:00:00 is already populated
# 2020-05-28 00:00:00 is already populated
# 2020-05-29 00:00:00 is already populated
# 2020-05-30 00:00:00 is already populated
# 2020-05-31 00:00:00 is already populated
# 2020-06-01 00:00:00 is already populated
# 2020-06-02 00:00:00 is already populated
# 2020-06-03 00:00:00 is already populated
# 2020-06-04 00:00:00 is already populated
# 2020-06-05 00:00:00 is already populated
# 2020-06-06 00:00:00 is already populated
# 2020-06-07 00:00:00 is already populated
# 2020-06-08 00:00:00 is already populated
# 2020-06-09 00:00:00 is already populated
# 2020-06-10 00:00:00 is already populated
# 2020-06-11 00:00:00 is already populated
# 2020-06-12 00:00:00 is already populated
# 2020-06-13 00:00:00 is already populated
# 2020-06-14 00:00:00 is already populated
# 2020-06-15 00:00:00 is already populated
# 2020-06-16 00:00:00 is already populated
# 2020-06-17 00:00:00 is already populated
# 2020-06-18 00:00:00 is already populated
# 2020-06-19 00:00:00 is already populated
# 2020-06-20 00:00:00 is already populated
# 2020-06-21 00:00:00 is already populated
# 2020-06-22 00:00:00 is already populated
# 2020-06-23 00:00:00 is already populated
# 2020-06-24 00:00:00 is already populated
# 2020-06-25 00:00:00 is already populated
# 2020-06-26 00:00:00 is already populated
# 2020-06-27 00:00:00 is already populated
# 2020-06-28 00:00:00 is already populated
# 2020-06-29 00:00:00 is already populated
# 2020-06-30 00:00:00 is already populated
# 2020-07-01 00:00:00 is already populated
# 2020-07-02 00:00:00 is already populated
# 2020-07-03 00:00:00 is already populated
# 2020-07-04 00:00:00 is already populated
# 2020-07-05 00:00:00 is already populated
# 2020-07-06 00:00:00 is already populated
# 2020-07-07 00:00:00 is already populated
# 2020-07-08 00:00:00 is already populated
# 2020-07-09 00:00:00 is already populated
# 2020-07-10 00:00:00 is already populated
# 2020-07-11 00:00:00 is already populated
# 2020-07-12 00:00:00 is already populated
# 2020-07-13 00:00:00 is already populated
# 2020-07-14 00:00:00 is already populated
# 2020-07-15 00:00:00 is already populated
# 2020-07-16 00:00:00 is already populated
# 2020-07-17 00:00:00 is already populated
# 2020-07-18 00:00:00 is already populated
# 2020-07-19 00:00:00 is already populated
# 2020-07-20 00:00:00 is already populated
# 2020-07-21 00:00:00 is already populated
# 2020-07-22 00:00:00 is already populated
# 2020-07-23 00:00:00 is already populated
# 2020-07-24 00:00:00 is already populated
# 2020-07-25 00:00:00 is already populated
# 2020-07-26 00:00:00 is already populated
# 2020-07-27 00:00:00 is already populated
# 2020-07-28 00:00:00 is already populated
# 2020-07-29 00:00:00 is already populated
# 2020-07-30 00:00:00 is already populated
# 2020-07-31 00:00:00 is already populated
# 2020-08-01 00:00:00 is already populated
# 2020-08-02 00:00:00 is already populated
# 2020-08-03 00:00:00 is already populated
# 2020-08-04 00:00:00 is already populated
# 2020-08-05 00:00:00 is already populated
# 2020-08-06 00:00:00 is already populated
# 2020-08-07 00:00:00 is already populated
# 2020-08-08 00:00:00 is already populated
# 2020-08-09 00:00:00 is already populated
# 2020-08-10 00:00:00 is already populated
# 2020-08-11 00:00:00 is already populated
# 2020-08-12 00:00:00 is already populated
# 2020-08-13 00:00:00 is already populated
# 2020-08-14 00:00:00 is already populated
# 2020-08-15 00:00:00 is already populated
# 2020-08-16 00:00:00 is already populated
# 2020-08-17 00:00:00 is already populated
# 2020-08-18 00:00:00 is already populated
# 2020-08-19 00:00:00 is already populated
# 2020-08-20 00:00:00 is already populated
# 2020-08-21 00:00:00 is already populated
# 2020-08-22 00:00:00 is already populated
# 2020-08-23 00:00:00 is already populated
# 2020-08-24 00:00:00 is already populated
# 2020-08-25 00:00:00 is already populated
# 2020-08-26 00:00:00 is already populated
# 2020-08-27 00:00:00 is already populated
# 2020-08-28 00:00:00 is already populated
# 2020-08-29 00:00:00 is already populated
# 2020-08-30 00:00:00 is already populated
# 2020-08-31 00:00:00 is already populated
# 2020-09-01 00:00:00 is already populated
# 2020-09-02 00:00:00 is already populated
# 2020-09-03 00:00:00 is already populated
# 2020-09-04 00:00:00 is already populated
# 2020-09-05 00:00:00 is already populated
# 2020-09-06 00:00:00 is already populated
# 2020-09-07 00:00:00 is already populated
# 2020-09-08 00:00:00 is already populated
# 2020-09-09 00:00:00 is already populated
# 2020-09-10 00:00:00 is already populated
# 2020-09-11 00:00:00 is already populated
# 2020-09-12 00:00:00 is already populated
# 2020-09-13 00:00:00 is already populated
# 2020-09-14 00:00:00 is already populated
# 2020-09-15 00:00:00 is already populated
# 2020-09-16 00:00:00 is already populated
# 2020-09-17 00:00:00 is already populated
# 2020-09-18 00:00:00 is already populated
# 2020-09-19 00:00:00 is already populated
# 2020-09-20 00:00:00 is already populated
# 2020-09-21 00:00:00 is already populated
# 2020-09-22 00:00:00 is already populated
# 2020-09-23 00:00:00 is already populated
# 2020-09-24 00:00:00 is already populated
# 2020-09-25 00:00:00 is already populated
# 2020-09-26 00:00:00 is already populated
# 2020-09-27 00:00:00 is already populated
# 2020-09-28 00:00:00 is already populated
# 2020-09-29 00:00:00 is already populated
# 2020-09-30 00:00:00 is already populated
# 2020-10-01 00:00:00 is already populated
# 2020-10-02 00:00:00 is already populated
# 2020-10-03 00:00:00 is already populated
# 2020-10-04 00:00:00 is already populated
# 2020-10-05 00:00:00 is already populated
# 2020-10-06 00:00:00 is already populated
# 2020-10-07 00:00:00 is already populated
# 2020-10-08 00:00:00 is already populated
# 2020-10-09 00:00:00 is already populated
# 2020-10-10 00:00:00 is already populated
# 2020-10-11 00:00:00 is already populated
# 2020-10-12 00:00:00 is already populated
# 2020-10-13 00:00:00 is already populated
# 2020-10-14 00:00:00 is already populated
# 2020-10-15 00:00:00 is already populated
# 2020-10-16 00:00:00 is already populated
# 2020-10-17 00:00:00 is already populated
# 2020-10-18 00:00:00 is already populated
# 2020-10-19 00:00:00 is already populated
# 2020-10-20 00:00:00 is already populated
# 2020-10-21 00:00:00 is already populated
# 2020-10-22 00:00:00 is already populated
# 2020-10-23 00:00:00 is already populated
# 2020-10-24 00:00:00 is already populated
# 2020-10-25 00:00:00 is already populated
# 2020-10-26 00:00:00 is already populated
# 2020-10-27 00:00:00 is already populated
# 2020-10-28 00:00:00 is already populated
# 2020-10-29 00:00:00 is already populated
# 2020-10-30 00:00:00 is already populated
# 2020-10-31 00:00:00 is already populated
# 2020-11-01 00:00:00 is already populated
# 2020-11-02 00:00:00 is already populated
# 2020-11-03 00:00:00 is already populated
# 2020-11-04 00:00:00 is already populated
# 2020-11-05 00:00:00 is already populated
# 2020-11-06 00:00:00 is already populated
# 2020-11-07 00:00:00 is already populated
# 2020-11-08 00:00:00 is already populated
# 2020-11-09 00:00:00 is already populated
# 2020-11-10 00:00:00 is already populated
# 2020-11-11 00:00:00 is already populated
# 2020-11-12 00:00:00 is already populated
# 2020-11-13 00:00:00 is already populated
# 2020-11-14 00:00:00 is already populated
# 2020-11-15 00:00:00 is already populated
# 2020-11-16 00:00:00 is already populated
# 2020-11-17 00:00:00 is already populated
# 2020-11-18 00:00:00 is already populated
# 2020-11-19 00:00:00 is already populated
# 2020-11-20 00:00:00 is already populated
# 2020-11-21 00:00:00 is already populated
# 2020-11-22 00:00:00 is already populated
# 2020-11-23 00:00:00 is already populated
# 2020-11-24 00:00:00 is already populated
# 2020-11-25 00:00:00 is already populated
# 2020-11-26 00:00:00 is already populated
# 2020-11-27 00:00:00 is already populated
# 2020-11-28 00:00:00 is already populated
# 2020-11-29 00:00:00 is already populated
# 2020-11-30 00:00:00 is already populated
# 2020-12-01 00:00:00 is already populated
# 2020-12-02 00:00:00 is already populated
# 2020-12-03 00:00:00 is already populated
# 2020-12-04 00:00:00 is already populated
# 2020-12-05 00:00:00 is already populated
# 2020-12-06 00:00:00 is already populated
# 2020-12-07 00:00:00 is already populated
# 2020-12-08 00:00:00 is already populated
# 2020-12-09 00:00:00 is already populated
# 2020-12-10 00:00:00 is already populated
# 2020-12-11 00:00:00 is already populated
# 2020-12-12 00:00:00 is already populated
# 2020-12-13 00:00:00 is already populated
# 2020-12-14 00:00:00 is already populated
# 2020-12-15 00:00:00 is already populated
# 2020-12-16 00:00:00 is already populated
# 2020-12-17 00:00:00 is already populated
# 2020-12-18 00:00:00 is already populated
# 2020-12-19 00:00:00 is already populated
# 2020-12-20 00:00:00 is already populated
# 2020-12-21 00:00:00 is already populated
# 2020-12-22 00:00:00 is already populated
# 2020-12-23 00:00:00 is already populated
# 2020-12-24 00:00:00 is already populated
# 2020-12-25 00:00:00 is already populated
# 2020-12-26 00:00:00 is already populated
# 2020-12-27 00:00:00 is already populated
# 2020-12-28 00:00:00 is already populated
# 2020-12-29 00:00:00 is already populated
# 2020-12-30 00:00:00 is already populated
# 2020-12-31 00:00:00 is already populated
# 2021-01-01 00:00:00 is already populated
# 2021-01-02 00:00:00 is already populated
# 2021-01-03 00:00:00 is already populated
# 2021-01-04 00:00:00 is already populated
# 2021-01-05 00:00:00 is already populated
# 2021-01-06 00:00:00 is already populated
# 2021-01-07 00:00:00 is already populated
# 2021-01-08 00:00:00 is already populated
# 2021-01-09 00:00:00 is already populated
# 2021-01-10 00:00:00 is already populated
# 2021-01-11 00:00:00 is already populated
# 2021-01-12 00:00:00 is already populated
# 2021-01-13 00:00:00 is already populated
# 2021-01-14 00:00:00 is already populated
# 2021-01-15 00:00:00 is already populated
# 2021-01-16 00:00:00 is already populated
# 2021-01-17 00:00:00 is already populated
# 2021-01-18 00:00:00 is already populated
# 2021-01-19 00:00:00 is already populated
# 2021-01-20 00:00:00 is already populated
# 2021-01-21 00:00:00 is already populated
# 2021-01-22 00:00:00 is already populated
# 2021-01-23 00:00:00 is already populated
# 2021-01-24 00:00:00 is already populated
# 2021-01-25 00:00:00 is already populated
# 2021-01-26 00:00:00 is already populated
# 2021-01-27 00:00:00 is already populated
# 2021-01-28 00:00:00 is already populated
# 2021-01-29 00:00:00 is already populated
# 2021-01-30 00:00:00 is already populated
# 2021-01-31 00:00:00 is already populated
# 2021-02-01 00:00:00 is already populated
# 2021-02-02 00:00:00 is already populated
# 2021-02-03 00:00:00 is already populated
# 2021-02-04 00:00:00 is already populated
# 2021-02-05 00:00:00 is already populated
# 2021-02-06 00:00:00 is already populated
# 2021-02-07 00:00:00 is already populated
# 2021-02-08 00:00:00 is already populated
# 2021-02-09 00:00:00 is already populated
# 2021-02-10 00:00:00 is already populated
# 2021-02-11 00:00:00 is already populated
# 2021-02-12 00:00:00 is already populated
# 2021-02-13 00:00:00 is already populated
# 2021-02-14 00:00:00 is already populated
# 2021-02-15 00:00:00 is already populated
# 2021-02-16 00:00:00 is already populated
# 2021-02-17 00:00:00 is already populated
# 2021-02-18 00:00:00 is already populated
# 2021-02-19 00:00:00 is already populated
# 2021-02-20 00:00:00 is already populated
# 2021-02-21 00:00:00 is already populated
# 2021-02-22 00:00:00 is already populated
# 2021-02-23 00:00:00 is already populated
# 2021-02-24 00:00:00 is already populated
# 2021-02-25 00:00:00 is already populated
# 2021-02-26 00:00:00 is already populated
# 2021-02-27 00:00:00 is already populated
# 2021-02-28 00:00:00 is already populated
# 2021-03-01 00:00:00 is already populated
# 2021-03-02 00:00:00 is already populated
# 2021-03-03 00:00:00 is already populated
# 2021-03-04 00:00:00 is already populated
# 2021-03-05 00:00:00 is already populated
# 2021-03-06 00:00:00 is already populated
# 2021-03-07 00:00:00 is already populated
# 2021-03-08 00:00:00 is already populated
# 2021-03-09 00:00:00 is already populated
# 2021-03-10 00:00:00 is already populated
# 2021-03-11 00:00:00 is already populated
# 2021-03-12 00:00:00 is already populated
# 2021-03-13 00:00:00 is already populated
# 2021-03-14 00:00:00 is already populated
# 2021-03-15 00:00:00 is already populated
# 2021-03-16 00:00:00 is already populated
# 2021-03-17 00:00:00 is already populated
# 2021-03-18 00:00:00 is already populated
# 2021-03-19 00:00:00 is already populated
# 2021-03-20 00:00:00 is already populated
# 2021-03-21 00:00:00 is already populated
# 2021-03-22 00:00:00 is already populated
# 2021-03-23 00:00:00 is already populated
# 2021-03-24 00:00:00 is already populated
# 2021-03-25 00:00:00 is already populated
# 2021-03-26 00:00:00 is already populated
# 2021-03-27 00:00:00 is already populated
# 2021-03-28 00:00:00 is already populated
# 2021-03-29 00:00:00 is already populated
# 2021-03-30 00:00:00 is already populated
# 2021-03-31 00:00:00 is already populated
# 2021-04-01 00:00:00 is already populated
# 2021-04-02 00:00:00 is already populated
# 2021-04-03 00:00:00 is already populated
# 2021-04-04 00:00:00 is already populated
# 2021-04-05 00:00:00 is already populated
# 2021-04-06 00:00:00 is already populated
# 2021-04-07 00:00:00 is already populated
# 2021-04-08 00:00:00 is already populated
# 2021-04-09 00:00:00 is already populated
# 2021-04-10 00:00:00 is already populated
# 2021-04-11 00:00:00 is already populated
# 2021-04-12 00:00:00 is already populated
# 2021-04-13 00:00:00 is already populated
# 2021-04-14 00:00:00 is already populated
# 2021-04-15 00:00:00 is already populated
# 2021-04-16 00:00:00 is already populated
# 2021-04-17 00:00:00 is already populated
# 2021-04-18 00:00:00 is already populated
# 2021-04-19 00:00:00 is already populated
# 2021-04-20 00:00:00 is already populated
# 2021-04-21 00:00:00 is already populated
# 2021-04-22 00:00:00 is already populated
# 2021-04-23 00:00:00 is already populated
# 2021-04-24 00:00:00 is already populated
# 2021-04-25 00:00:00 is already populated
# 2021-04-26 00:00:00 is already populated
# 2021-04-27 00:00:00 is already populated
# 2021-04-28 00:00:00 is already populated
# 2021-04-29 00:00:00 is already populated
# 2021-04-30 00:00:00 is already populated
# 2021-05-01 00:00:00 is already populated
# 2021-05-02 00:00:00 is already populated
# 2021-05-03 00:00:00 is already populated
# 2021-05-04 00:00:00 is already populated
# 2021-05-05 00:00:00 is already populated
# 2021-05-06 00:00:00 is already populated
# 2021-05-07 00:00:00 is already populated
# 2021-05-08 00:00:00 is already populated
# 2021-05-09 00:00:00 is already populated
# 2021-05-10 00:00:00 is already populated
# 2021-05-11 00:00:00 is already populated
# 2021-05-12 00:00:00 is already populated
# 2021-05-13 00:00:00 is already populated
# 2021-05-14 00:00:00 is already populated
# 2021-05-15 00:00:00 is already populated
# 2021-05-16 00:00:00 is already populated
# 2021-05-17 00:00:00 is already populated
# 2021-05-18 00:00:00 is already populated
# 2021-05-19 00:00:00 is already populated
# 2021-05-20 00:00:00 is already populated
# 2021-05-21 00:00:00 is already populated
# 2021-05-22 00:00:00 is already populated
# 2021-05-23 00:00:00 is already populated
# 2021-05-24 00:00:00 is already populated
# 2021-05-25 00:00:00 is already populated
# 2021-05-26 00:00:00 is already populated
# 2021-05-27 00:00:00 is already populated
# 2021-05-28 00:00:00 is already populated
# 2021-05-29 00:00:00 is already populated
# 2021-05-30 00:00:00 is already populated
# 2021-05-31 00:00:00 is already populated
# 2021-06-01 00:00:00 is already populated
# 2021-06-02 00:00:00 is already populated
# 2021-06-03 00:00:00 is already populated
# 2021-06-04 00:00:00 is already populated
# 2021-06-05 00:00:00 is already populated
# 2021-06-06 00:00:00 is already populated
# 2021-06-07 00:00:00 is already populated
# 2021-06-08 00:00:00 is already populated
# 2021-06-09 00:00:00 is already populated
# 2021-06-10 00:00:00 is already populated
# 2021-06-11 00:00:00 is already populated
# 2021-06-12 00:00:00 is already populated
# 2021-06-13 00:00:00 is already populated
# 2021-06-14 00:00:00 is already populated
# 2021-06-15 00:00:00 is already populated
# 2021-06-16 00:00:00 is already populated
# 2021-06-17 00:00:00 is already populated
# 2021-06-18 00:00:00 is already populated
# 2021-06-19 00:00:00 is already populated
# 2021-06-20 00:00:00 is already populated
# 2021-06-21 00:00:00 is already populated
# 2021-06-22 00:00:00 is already populated
# 2021-06-23 00:00:00 is already populated
# 2021-06-24 00:00:00 is already populated
# 2021-06-25 00:00:00 is already populated
# 2021-06-26 00:00:00 is already populated
# 2021-06-27 00:00:00 is already populated
# 2021-06-28 00:00:00 is already populated
# 2021-06-29 00:00:00 is already populated
# 2021-06-30 00:00:00 is already populated
# 2021-07-01 00:00:00 is already populated
# 2021-07-02 00:00:00 is already populated
# 2021-07-03 00:00:00 is already populated
# 2021-07-04 00:00:00 is already populated
# 2021-07-05 00:00:00 is already populated
# 2021-07-06 00:00:00 is already populated
# 2021-07-07 00:00:00 is already populated
# 2021-07-08 00:00:00 is already populated
# 2021-07-09 00:00:00 is already populated
# 2021-07-10 00:00:00 is already populated
# 2021-07-11 00:00:00 is already populated
# 2021-07-12 00:00:00 is already populated
# 2021-07-13 00:00:00 is already populated
# 2021-07-14 00:00:00 is already populated
# 2021-07-15 00:00:00 is already populated
# 2021-07-16 00:00:00 is already populated
# 2021-07-17 00:00:00 is already populated
# 2021-07-18 00:00:00 is already populated
# 2021-07-19 00:00:00 is already populated
# 2021-07-20 00:00:00 is already populated
# 2021-07-21 00:00:00 is already populated
# 2021-07-22 00:00:00 is already populated
# 2021-07-23 00:00:00 is already populated
# 2021-07-24 00:00:00 is already populated
# 2021-07-25 00:00:00 is already populated
# 2021-07-26 00:00:00 is already populated
# 2021-07-27 00:00:00 is already populated
# 2021-07-28 00:00:00 is already populated
# 2021-07-29 00:00:00 is already populated
# 2021-07-30 00:00:00 is already populated
# 2021-07-31 00:00:00 is already populated
# 2021-08-01 00:00:00 is already populated
# 2021-08-02 00:00:00 is already populated
# 2021-08-03 00:00:00 is already populated
# 2021-08-04 00:00:00 is already populated
# 2021-08-05 00:00:00 is already populated
# 2021-08-06 00:00:00 is already populated
# 2021-08-07 00:00:00 is already populated
# 2021-08-08 00:00:00 is already populated
# 2021-08-09 00:00:00 is already populated
# 2021-08-10 00:00:00 is already populated
# 2021-08-11 00:00:00 is already populated
# 2021-08-12 00:00:00 is already populated
# 2021-08-13 00:00:00 is already populated
# 2021-08-14 00:00:00 is already populated
# 2021-08-15 00:00:00 is already populated
# 2021-08-16 00:00:00 is already populated
# 2021-08-17 00:00:00 is already populated
# 2021-08-18 00:00:00 is already populated
# 2021-08-19 00:00:00 is already populated
# 2021-08-20 00:00:00 is already populated
# 2021-08-21 00:00:00 is already populated
# 2021-08-22 00:00:00 is already populated
# 2021-08-23 00:00:00 is already populated
# 2021-08-24 00:00:00 is already populated
# 2021-08-25 00:00:00 is already populated
# 2021-08-26 00:00:00 is already populated
# 2021-08-27 00:00:00 is already populated
# 2021-08-28 00:00:00 is already populated
# 2021-08-29 00:00:00 is already populated
# 2021-08-30 00:00:00 is already populated
# 2021-08-31 00:00:00 is already populated
# 2021-09-01 00:00:00 is already populated
# 2021-09-02 00:00:00 is already populated
# 2021-09-03 00:00:00 is already populated
# 2021-09-04 00:00:00 is already populated
# 2021-09-05 00:00:00 is already populated
# 2021-09-06 00:00:00 is already populated
# 2021-09-07 00:00:00 is already populated
# 2021-09-08 00:00:00 is already populated
# 2021-09-09 00:00:00 is already populated
# 2021-09-10 00:00:00 is already populated
# 2021-09-11 00:00:00 is already populated
# 2021-09-12 00:00:00 is already populated
# 2021-09-13 00:00:00 is already populated
# 2021-09-14 00:00:00 is already populated
# 2021-09-15 00:00:00 is already populated
# 2021-09-16 00:00:00 is already populated
# 2021-09-17 00:00:00 is already populated
# 2021-09-18 00:00:00 is already populated
# 2021-09-19 00:00:00 is already populated
# 2021-09-20 00:00:00 is already populated
# 2021-09-21 00:00:00 is already populated
# 2021-09-22 00:00:00 is already populated
# 2021-09-23 00:00:00 is already populated
# 2021-09-24 00:00:00 is already populated
# 2021-09-25 00:00:00 is already populated
# 2021-09-26 00:00:00 is already populated
# 2021-09-27 00:00:00 is already populated
# 2021-09-28 00:00:00 is already populated
# 2021-09-29 00:00:00 is already populated
# 2021-09-30 00:00:00 is already populated
# 2021-10-01 00:00:00 is already populated
# 2021-10-02 00:00:00 is already populated
# 2021-10-03 00:00:00 is already populated
# 2021-10-04 00:00:00 is already populated
# 2021-10-05 00:00:00 is already populated
# 2021-10-06 00:00:00 is already populated
# 2021-10-07 00:00:00 is already populated
# 2021-10-08 00:00:00 is already populated
# 2021-10-09 00:00:00 is already populated
# 2021-10-10 00:00:00 is already populated
# 2021-10-11 00:00:00 is already populated
# 2021-10-12 00:00:00 is already populated
# 2021-10-13 00:00:00 is already populated
# 2021-10-14 00:00:00 is already populated
# 2021-10-15 00:00:00 is already populated
# 2021-10-16 00:00:00 is already populated
# 2021-10-17 00:00:00 is already populated
# 2021-10-18 00:00:00 is already populated
# 2021-10-19 00:00:00 is already populated
# 2021-10-20 00:00:00 is already populated
# 2021-10-21 00:00:00 is already populated
# 2021-10-22 00:00:00 is already populated
# 2021-10-23 00:00:00 is already populated
# 2021-10-24 00:00:00 is already populated
# 2021-10-25 00:00:00 is already populated
# 2021-10-26 00:00:00 is already populated
# 2021-10-27 00:00:00 is already populated
# 2021-10-28 00:00:00 is already populated
# 2021-10-29 00:00:00 is already populated
# 2021-10-30 00:00:00 is already populated
# 2021-10-31 00:00:00 is already populated
# 2021-11-01 00:00:00 is already populated
# 2021-11-02 00:00:00 is already populated
# 2021-11-03 00:00:00 is already populated
# 2021-11-04 00:00:00 is already populated
# 2021-11-05 00:00:00 is already populated
# 2021-11-06 00:00:00 is already populated
# 2021-11-07 00:00:00 is already populated
# 2021-11-08 00:00:00 is already populated
# 2021-11-09 00:00:00 is already populated
# 2021-11-10 00:00:00 is already populated
# 2021-11-11 00:00:00 is already populated
# 2021-11-12 00:00:00 is already populated
# 2021-11-13 00:00:00 is already populated
# 2021-11-14 00:00:00 is already populated
# 2021-11-15 00:00:00 is already populated
# 2021-11-16 00:00:00 is already populated
# 2021-11-17 00:00:00 is already populated
# 2021-11-18 00:00:00 is already populated
# 2021-11-19 00:00:00 is already populated
# 2021-11-20 00:00:00 is already populated
# 2021-11-21 00:00:00 is already populated
# 2021-11-22 00:00:00 is already populated
# 2021-11-23 00:00:00 is already populated
# 2021-11-24 00:00:00 is already populated
# 2021-11-25 00:00:00 is already populated
# 2021-11-26 00:00:00 is already populated
# 2021-11-27 00:00:00 is already populated
# 2021-11-28 00:00:00 is already populated
# 2021-11-29 00:00:00 is already populated
# 2021-11-30 00:00:00 is already populated
# 2021-12-01 00:00:00 is already populated
# 2021-12-02 00:00:00 is already populated
# 2021-12-03 00:00:00 is already populated
# 2021-12-04 00:00:00 is already populated
# 2021-12-05 00:00:00 is already populated
# 2021-12-06 00:00:00 is already populated
# 2021-12-07 00:00:00 is already populated
# 2021-12-08 00:00:00 is already populated
# 2021-12-09 00:00:00 is already populated
# 2021-12-10 00:00:00 is already populated
# 2021-12-11 00:00:00 is already populated
# 2021-12-12 00:00:00 is already populated
# 2021-12-13 00:00:00 is already populated
# 2021-12-14 00:00:00 is already populated
# 2021-12-15 00:00:00 is already populated
# 2021-12-16 00:00:00 is already populated
# 2021-12-17 00:00:00 is already populated
# 2021-12-18 00:00:00 is already populated
# 2021-12-19 00:00:00 is already populated
# 2021-12-20 00:00:00 is already populated
# 2021-12-21 00:00:00 is already populated
# 2021-12-22 00:00:00 is already populated
# 2021-12-23 00:00:00 is already populated
# 2021-12-24 00:00:00 is already populated
# 2021-12-25 00:00:00 is already populated
# 2021-12-26 00:00:00 is already populated
# 2021-12-27 00:00:00 is already populated
# 2021-12-28 00:00:00 is already populated
# 2021-12-29 00:00:00 is already populated
# 2021-12-30 00:00:00 is already populated
# 2021-12-31 00:00:00 is already populated
# 2022-01-01 00:00:00 is already populated
# 2022-01-02 00:00:00 is already populated
# 2022-01-03 00:00:00 is already populated
# 2022-01-04 00:00:00 is already populated
# 2022-01-05 00:00:00 is already populated
# 2022-01-06 00:00:00 is already populated
# 2022-01-07 00:00:00 is already populated
# 2022-01-08 00:00:00 is already populated
# 2022-01-09 00:00:00 is already populated
# 2022-01-10 00:00:00 is already populated
# 2022-01-11 00:00:00 is already populated
# 2022-01-12 00:00:00 is already populated
# 2022-01-13 00:00:00 is already populated
# 2022-01-14 00:00:00 is already populated
# 2022-01-15 00:00:00 is already populated
# 2022-01-16 00:00:00 is already populated
# 2022-01-17 00:00:00 is already populated
# 2022-01-18 00:00:00 is already populated
# 2022-01-19 00:00:00 is already populated
# 2022-01-20 00:00:00 is already populated
# 2022-01-21 00:00:00 is already populated
# 2022-01-22 00:00:00 is already populated
# 2022-01-23 00:00:00 is already populated
# 2022-01-24 00:00:00 is already populated
# 2022-01-25 00:00:00 is already populated
# 2022-01-26 00:00:00 is already populated
# 2022-01-27 00:00:00 is already populated
# 2022-01-28 00:00:00 is already populated
# 2022-01-29 00:00:00 is already populated
# 2022-01-30 00:00:00 is already populated
# 2022-01-31 00:00:00 is already populated
# 2022-02-01 00:00:00 is already populated
# 2022-02-02 00:00:00 is already populated
# 2022-02-03 00:00:00 is already populated
# 2022-02-04 00:00:00 is already populated
# 2022-02-05 00:00:00 is already populated
# 2022-02-06 00:00:00 is already populated
# 2022-02-07 00:00:00 is already populated
# 2022-02-08 00:00:00 is already populated
# 2022-02-09 00:00:00 is already populated
# 2022-02-10 00:00:00 is already populated
# 2022-02-11 00:00:00 is already populated
# 2022-02-12 00:00:00 is already populated
# 2022-02-13 00:00:00 is already populated
# 2022-02-14 00:00:00 is already populated
# 2022-02-15 00:00:00 is already populated
# 2022-02-16 00:00:00 is already populated
# 2022-02-17 00:00:00 is already populated
# 2022-02-18 00:00:00 is already populated
# 2022-02-19 00:00:00 is already populated
# 2022-02-20 00:00:00 is already populated
# 2022-02-21 00:00:00 is already populated
# 2022-02-22 00:00:00 is already populated
# 2022-02-23 00:00:00 is already populated
# 2022-02-24 00:00:00 is already populated
# 2022-02-25 00:00:00 is already populated
# 2022-02-26 00:00:00 is already populated
# 2022-02-27 00:00:00 is already populated
# 2022-02-28 00:00:00 is already populated
# 2022-03-01 00:00:00 is already populated
# 2022-03-02 00:00:00 is already populated
# 2022-03-03 00:00:00 is already populated
# 2022-03-04 00:00:00 is already populated
# 2022-03-05 00:00:00 is already populated
# 2022-03-06 00:00:00 is already populated
# 2022-03-07 00:00:00 is already populated
# 2022-03-08 00:00:00 is already populated
# 2022-03-09 00:00:00 is already populated
# 2022-03-10 00:00:00 is already populated
# 2022-03-11 00:00:00 is already populated
# 2022-03-12 00:00:00 is already populated
# 2022-03-13 00:00:00 is already populated
# 2022-03-14 00:00:00 is already populated
# 2022-03-15 00:00:00 is already populated
# 2022-03-16 00:00:00 is already populated
# 2022-03-17 00:00:00 is already populated
# 2022-03-18 00:00:00 is already populated
# 2022-03-19 00:00:00 is already populated
# 2022-03-20 00:00:00 is already populated
# 2022-03-21 00:00:00 is already populated
# 2022-03-22 00:00:00 is already populated
# 2022-03-23 00:00:00 is already populated
# 2022-03-24 00:00:00 is already populated
# 2022-03-25 00:00:00 is already populated
# 2022-03-26 00:00:00 is already populated
# 2022-03-27 00:00:00 is already populated
# 2022-03-28 00:00:00 is already populated
# 2022-03-29 00:00:00 is already populated
# 2022-03-30 00:00:00 is already populated
# 2022-03-31 00:00:00 is already populated
# 2022-04-01 00:00:00 is already populated
# 2022-04-02 00:00:00 is already populated
# 2022-04-03 00:00:00 is already populated
# 2022-04-04 00:00:00 is already populated
# 2022-04-05 00:00:00 is already populated
# 2022-04-06 00:00:00 is already populated
# 2022-04-07 00:00:00 is already populated
# 2022-04-08 00:00:00 is already populated
# 2022-04-09 00:00:00 is already populated
# 2022-04-10 00:00:00 is already populated
# 2022-04-11 00:00:00 is already populated
# 2022-04-12 00:00:00 is already populated
# 2022-04-13 00:00:00 is already populated
# 2022-04-14 00:00:00 is already populated
# 2022-04-15 00:00:00 is already populated
# 2022-04-16 00:00:00 is already populated
# 2022-04-17 00:00:00 is already populated
# 2022-04-18 00:00:00 is already populated
# 2022-04-19 00:00:00 is already populated
# 2022-04-20 00:00:00 is already populated
# 2022-04-21 00:00:00 is already populated
# 2022-04-22 00:00:00 is already populated
# 2022-04-23 00:00:00 is already populated
# 2022-04-24 00:00:00 is already populated
# 2022-04-25 00:00:00 is already populated
# 2022-04-26 00:00:00 is already populated
# 2022-04-27 00:00:00 is already populated
# 2022-04-28 00:00:00 is already populated
# 2022-04-29 00:00:00 is already populated
# 2022-04-30 00:00:00 is already populated
# 2022-05-01 00:00:00 is already populated
# 2022-05-02 00:00:00 is already populated
# 2022-05-03 00:00:00 is already populated
# 2022-05-04 00:00:00 is already populated
# 2022-05-05 00:00:00 is already populated
# 2022-05-06 00:00:00 is already populated
# 2022-05-07 00:00:00 is already populated
# 2022-05-08 00:00:00 is already populated
# 2022-05-09 00:00:00 is already populated
# 2022-05-10 00:00:00 is already populated
# 2022-05-11 00:00:00 is already populated
# 2022-05-12 00:00:00 is already populated
# 2022-05-13 00:00:00 is already populated
# 2022-05-14 00:00:00 is already populated
# 2022-05-15 00:00:00 is already populated
# 2022-05-16 00:00:00 is already populated
# 2022-05-17 00:00:00 is already populated
# 2022-05-18 00:00:00 is already populated
# 2022-05-19 00:00:00 is already populated
# 2022-05-20 00:00:00 is already populated
# 2022-05-21 00:00:00 is already populated
# 2022-05-22 00:00:00 is already populated
# 2022-05-23 00:00:00 is already populated
# 2022-05-24 00:00:00 is already populated
# 2022-05-25 00:00:00 is already populated
# 2022-05-26 00:00:00 is already populated
# 2022-05-27 00:00:00 is already populated
# 2022-05-28 00:00:00 is already populated
# 2022-05-29 00:00:00 is already populated
# 2022-05-30 00:00:00 is already populated
# 2022-05-31 00:00:00 is already populated
# 2022-06-01 00:00:00 is already populated
# 2022-06-02 00:00:00 is already populated
# 2022-06-03 00:00:00 is already populated
# 2022-06-04 00:00:00 is already populated
# 2022-06-05 00:00:00 is already populated
# 2022-06-06 00:00:00 is already populated
# 2022-06-07 00:00:00 is already populated
# 2022-06-08 00:00:00 is already populated
# 2022-06-09 00:00:00 is already populated
# 2022-06-10 00:00:00 is already populated
# 2022-06-11 00:00:00 is already populated
# 2022-06-12 00:00:00 is already populated
# 2022-06-13 00:00:00 is already populated
# 2022-06-14 00:00:00 is already populated
# 2022-06-15 00:00:00 is already populated
# 2022-06-16 00:00:00 is already populated
# 2022-06-17 00:00:00 is already populated
# 2022-06-18 00:00:00 is already populated
# 2022-06-19 00:00:00 is already populated
# 2022-06-20 00:00:00 is already populated
# 2022-06-21 00:00:00 is already populated
# 2022-06-22 00:00:00 is already populated
# 2022-06-23 00:00:00 is already populated
# 2022-06-24 00:00:00 is already populated
# 2022-06-25 00:00:00 is already populated
# 2022-06-26 00:00:00 is already populated
# 2022-06-27 00:00:00 is already populated
# 2022-06-28 00:00:00 is already populated
# 2022-06-29 00:00:00 is already populated
# 2022-06-30 00:00:00 is already populated
# 2022-07-01 00:00:00 is already populated
# 2022-07-02 00:00:00 is already populated
# 2022-07-03 00:00:00 is already populated
# 2022-07-04 00:00:00 is already populated
# 2022-07-05 00:00:00 is already populated
# 2022-07-06 00:00:00 is already populated
# 2022-07-07 00:00:00 is already populated
# 2022-07-08 00:00:00 is already populated
# 2022-07-09 00:00:00 is already populated
# 2022-07-10 00:00:00 is already populated
# 2022-07-11 00:00:00 is already populated
# 2022-07-12 00:00:00 is already populated
# 2022-07-13 00:00:00 is already populated
# 2022-07-14 00:00:00 is already populated
# 2022-07-15 00:00:00 is already populated
# 2022-07-16 00:00:00 is already populated
# 2022-07-17 00:00:00 is already populated
# 2022-07-18 00:00:00 is already populated
# 2022-07-19 00:00:00 is already populated
# 2022-07-20 00:00:00 is already populated
# 2022-07-21 00:00:00 is already populated
# 2022-07-22 00:00:00 is already populated
# 2022-07-23 00:00:00 is already populated
# 2022-07-24 00:00:00 is already populated
# 2022-07-25 00:00:00 is already populated
# 2022-07-26 00:00:00 is already populated
# 2022-07-27 00:00:00 is already populated
# 2022-07-28 00:00:00 is already populated
# 2022-07-29 00:00:00 is already populated
# 2022-07-30 00:00:00 is already populated
# 2022-07-31 00:00:00 is already populated
# 2022-08-01 00:00:00 is already populated
# 2022-08-02 00:00:00 is already populated
# 2022-08-03 00:00:00 is already populated
# 2022-08-04 00:00:00 is already populated
# 2022-08-05 00:00:00 is already populated
# 2022-08-06 00:00:00 is already populated
# 2022-08-07 00:00:00 is already populated
# 2022-08-08 00:00:00 is already populated
# 2022-08-09 00:00:00 is already populated
# 2022-08-10 00:00:00 is already populated
# 2022-08-11 00:00:00 is already populated
# 2022-08-12 00:00:00 is already populated
# 2022-08-13 00:00:00 is already populated
# 2022-08-14 00:00:00 is already populated
# 2022-08-15 00:00:00 is already populated
# 2022-08-16 00:00:00 is already populated
# 2022-08-17 00:00:00 is already populated
# 2022-08-18 00:00:00 is already populated
# 2022-08-19 00:00:00 is already populated
# 2022-08-20 00:00:00 is already populated
# 2022-08-21 00:00:00 is already populated
# 2022-08-22 00:00:00 is already populated
# 2022-08-23 00:00:00 is already populated
# 2022-08-24 00:00:00 is already populated
# 2022-08-25 00:00:00 is already populated
# 2022-08-26 00:00:00 is already populated
# 2022-08-27 00:00:00 is already populated
# 2022-08-28 00:00:00 is already populated
# 2022-08-29 00:00:00 is already populated
# 2022-08-30 00:00:00 is already populated
# 2022-08-31 00:00:00 is already populated
# 2022-09-01 00:00:00 is already populated
# 2022-09-02 00:00:00 is already populated
# 2022-09-03 00:00:00 is already populated
# 2022-09-04 00:00:00 is already populated
# 2022-09-05 00:00:00 is already populated
# 2022-09-06 00:00:00 is already populated
# 2022-09-07 00:00:00 is already populated
# 2022-09-08 00:00:00 is already populated
# 2022-09-09 00:00:00 is already populated
# 2022-09-10 00:00:00 is already populated
# 2022-09-11 00:00:00 is already populated
# 2022-09-12 00:00:00 is already populated
# 2022-09-13 00:00:00 is already populated
# 2022-09-14 00:00:00 is already populated
# 2022-09-15 00:00:00 is already populated
# 2022-09-16 00:00:00 is already populated
# 2022-09-17 00:00:00 is already populated
# 2022-09-18 00:00:00 is already populated
# 2022-09-19 00:00:00 is already populated
# 2022-09-20 00:00:00 is already populated
# 2022-09-21 00:00:00 is already populated
# 2022-09-22 00:00:00 is already populated
# 2022-09-23 00:00:00 is already populated
# 2022-09-24 00:00:00 is already populated
# 2022-09-25 00:00:00 is already populated
# 2022-09-26 00:00:00 is already populated
# 2022-09-27 00:00:00 is already populated
# 2022-09-28 00:00:00 is already populated
# 2022-09-29 00:00:00 is already populated
# 2022-09-30 00:00:00 is already populated
# 2022-10-01 00:00:00 is already populated
# 2022-10-02 00:00:00 is already populated
# 2022-10-03 00:00:00 is already populated
# 2022-10-04 00:00:00 is already populated
# 2022-10-05 00:00:00 is already populated
# 2022-10-06 00:00:00 is already populated
# 2022-10-07 00:00:00 is already populated
# 2022-10-08 00:00:00 is already populated
# 2022-10-09 00:00:00 is already populated
# 2022-10-10 00:00:00 is already populated
# 2022-10-11 00:00:00 is already populated
# 2022-10-12 00:00:00 is already populated
# 2022-10-13 00:00:00 is already populated
# 2022-10-14 00:00:00 is already populated
# 2022-10-15 00:00:00 is already populated
# 2022-10-16 00:00:00 is already populated
# 2022-10-17 00:00:00 is already populated
# 2022-10-18 00:00:00 is already populated
# 2022-10-19 00:00:00 is already populated
# 2022-10-20 00:00:00 is already populated
# 2022-10-21 00:00:00 is already populated
# 2022-10-22 00:00:00 is already populated
# 2022-10-23 00:00:00 is already populated
# 2022-10-24 00:00:00 is already populated
# 2022-10-25 00:00:00 is already populated
# 2022-10-26 00:00:00 is already populated
# 2022-10-27 00:00:00 is already populated
# 2022-10-28 00:00:00 is already populated
# 2022-10-29 00:00:00 is already populated
# 2022-10-30 00:00:00 is already populated
# 2022-10-31 00:00:00 is already populated
# 2022-11-01 00:00:00 is already populated
# 2022-11-02 00:00:00 is already populated
# 2022-11-03 00:00:00 is already populated
# 2022-11-04 00:00:00 is already populated
# 2022-11-05 00:00:00 is already populated
# 2022-11-06 00:00:00 is already populated
# 2022-11-07 00:00:00 is already populated
# 2022-11-08 00:00:00 is already populated
# 2022-11-09 00:00:00 is already populated
# 2022-11-10 00:00:00 is already populated
# 2022-11-11 00:00:00 is already populated
# 2022-11-12 00:00:00 is already populated
# 2022-11-13 00:00:00 is already populated
# 2022-11-14 00:00:00 is already populated
# 2022-11-15 00:00:00 is already populated
# 2022-11-16 00:00:00 is already populated
# 2022-11-17 00:00:00 is already populated
# 2022-11-18 00:00:00 is already populated
# 2022-11-19 00:00:00 is already populated
# 2022-11-20 00:00:00 is already populated
# 2022-11-21 00:00:00 is already populated
# 2022-11-22 00:00:00 is already populated
# 2022-11-23 00:00:00 is already populated
# 2022-11-24 00:00:00 is already populated
# 2022-11-25 00:00:00 is already populated
# 2022-11-26 00:00:00 is already populated
# 2022-11-27 00:00:00 is already populated
# 2022-11-28 00:00:00 is already populated
# 2022-11-29 00:00:00 is already populated
# 2022-11-30 00:00:00 is already populated
# 2022-12-01 00:00:00 is already populated
# 2022-12-02 00:00:00 is already populated
# 2022-12-03 00:00:00 is already populated
# 2022-12-04 00:00:00 is already populated
# 2022-12-05 00:00:00 is already populated
# 2022-12-06 00:00:00 is already populated
# 2022-12-07 00:00:00 is already populated
# 2022-12-08 00:00:00 is already populated
# 2022-12-09 00:00:00 is already populated
# 2022-12-10 00:00:00 is already populated
# 2022-12-11 00:00:00 is already populated
# 2022-12-12 00:00:00 is already populated
# 2022-12-13 00:00:00 is already populated
# 2022-12-14 00:00:00 is already populated
# 2022-12-15 00:00:00 is already populated
# 2022-12-16 00:00:00 is already populated
# 2022-12-17 00:00:00 is already populated
# 2022-12-18 00:00:00 is already populated
# 2022-12-19 00:00:00 is already populated
# 2022-12-20 00:00:00 is already populated
# 2022-12-21 00:00:00 is already populated
# 2022-12-22 00:00:00 is already populated
# 2022-12-23 00:00:00 is already populated
# 2022-12-24 00:00:00 is already populated
# 2022-12-25 00:00:00 is already populated
# 2022-12-26 00:00:00 is already populated
# 2022-12-27 00:00:00 is already populated
# 2022-12-28 00:00:00 is already populated
# 2022-12-29 00:00:00 is already populated
# 2022-12-30 00:00:00 is already populated
# 2022-12-31 00:00:00 is already populated
# 2023-01-01 00:00:00 is already populated
# 2023-01-02 00:00:00 is already populated
# 2023-01-03 00:00:00 is already populated
# 2023-01-04 00:00:00 is already populated
# 2023-01-05 00:00:00 is already populated
# 2023-01-06 00:00:00 is already populated
# 2023-01-07 00:00:00 is already populated
# 2023-01-08 00:00:00 is already populated
# 2023-01-09 00:00:00 is already populated
# 2023-01-10 00:00:00 is already populated
# 2023-01-11 00:00:00 is already populated
# 2023-01-12 00:00:00 is already populated
# 2023-01-13 00:00:00 is already populated
# 2023-01-14 00:00:00 is already populated
# 2023-01-15 00:00:00 is already populated
# 2023-01-16 00:00:00 is already populated
# 2023-01-17 00:00:00 is already populated
# 2023-01-18 00:00:00 is already populated
# 2023-01-19 00:00:00 is already populated
# 2023-01-20 00:00:00 is already populated
# 2023-01-21 00:00:00 is already populated
# 2023-01-22 00:00:00 is already populated
# 2023-01-23 00:00:00 is already populated
# 2023-01-24 00:00:00 is already populated
# 2023-01-25 00:00:00 is already populated
# 2023-01-26 00:00:00 is already populated
# 2023-01-27 00:00:00 is already populated
# 2023-01-28 00:00:00 is already populated
# 2023-01-29 00:00:00 is already populated
# 2023-01-30 00:00:00 is already populated
# 2023-01-31 00:00:00 is already populated
# 2023-02-01 00:00:00 is already populated
# 2023-02-02 00:00:00 is already populated
# 2023-02-03 00:00:00 is already populated
# 2023-02-04 00:00:00 is already populated
# 2023-02-05 00:00:00 is already populated
# 2023-02-06 00:00:00 is already populated
# 2023-02-07 00:00:00 is already populated
# 2023-02-08 00:00:00 is already populated
# 2023-02-09 00:00:00 is already populated
# 2023-02-10 00:00:00 is already populated
# 2023-02-11 00:00:00 is already populated
# 2023-02-12 00:00:00 is already populated
# 2023-02-13 00:00:00 is already populated
# 2023-02-14 00:00:00 is already populated
# 2023-02-15 00:00:00 is already populated
# 2023-02-16 00:00:00 is already populated
# 2023-02-17 00:00:00 is already populated
# 2023-02-18 00:00:00 is already populated
# 2023-02-19 00:00:00 is already populated
# 2023-02-20 00:00:00 is already populated
# 2023-02-21 00:00:00 is already populated
# 2023-02-22 00:00:00 is already populated
# 2023-02-23 00:00:00 is already populated
# 2023-02-24 00:00:00 is already populated
# 2023-02-25 00:00:00 is already populated
# 2023-02-26 00:00:00 is already populated
# 2023-02-27 00:00:00 is already populated
# 2023-02-28 00:00:00 is already populated
# 2023-03-01 00:00:00 is already populated
# 2023-03-02 00:00:00 is already populated
# 2023-03-03 00:00:00 is already populated
# 2023-03-04 00:00:00 is already populated
# 2023-03-05 00:00:00 is already populated
# 2023-03-06 00:00:00 is already populated
# 2023-03-07 00:00:00 is already populated
# 2023-03-08 00:00:00 is already populated
# 2023-03-09 00:00:00 is already populated
# 2023-03-10 00:00:00 is already populated
# 2023-03-11 00:00:00 is already populated
# 2023-03-12 00:00:00 is already populated
# 2023-03-13 00:00:00 is already populated
# 2023-03-14 00:00:00 is already populated
# 2023-03-15 00:00:00 is already populated
# 2023-03-16 00:00:00 is already populated
# 2023-03-17 00:00:00 is already populated
# 2023-03-18 00:00:00 is already populated
# 2023-03-19 00:00:00 is already populated
# 2023-03-20 00:00:00 is already populated
# 2023-03-21 00:00:00 is already populated
# 2023-03-22 00:00:00 is already populated
# 2023-03-23 00:00:00 is already populated
# 2023-03-24 00:00:00 is already populated
# 2023-03-25 00:00:00 is already populated
# 2023-03-26 00:00:00 is already populated
# 2023-03-27 00:00:00 is already populated
# 2023-03-28 00:00:00 is already populated
# 2023-03-29 00:00:00 is already populated
# 2023-03-30 00:00:00 is already populated
# 2023-03-31 00:00:00 is already populated
# 2023-04-01 00:00:00 is already populated
# 2023-04-02 00:00:00 is already populated
# 2023-04-03 00:00:00 is already populated
# 2023-04-04 00:00:00 is already populated
# 2023-04-05 00:00:00 is already populated
# 2023-04-06 00:00:00 is already populated
# 2023-04-07 00:00:00 is already populated
# 2023-04-08 00:00:00 is already populated
# 2023-04-09 00:00:00 is already populated
# 2023-04-10 00:00:00 is already populated
# 2023-04-11 00:00:00 is already populated
# 2023-04-12 00:00:00 is already populated
# 2023-04-13 00:00:00 is already populated
# 2023-04-14 00:00:00 is already populated
# 2023-04-15 00:00:00 is already populated
# 2023-04-16 00:00:00 is already populated
# 2023-04-17 00:00:00 is already populated
# 2023-04-18 00:00:00 is already populated
# 2023-04-19 00:00:00 is already populated
# 2023-04-20 00:00:00 is already populated
# 2023-04-21 00:00:00 is already populated
# 2023-04-22 00:00:00 is already populated
# 2023-04-23 00:00:00 is already populated
# 2023-04-24 00:00:00 is already populated
# 2023-04-25 00:00:00 is already populated
# 2023-04-26 00:00:00 is already populated
# 2023-04-27 00:00:00 is already populated
# 2023-04-28 00:00:00 is already populated
# 2023-04-29 00:00:00 is already populated
# 2023-04-30 00:00:00 is already populated
# 2023-05-01 00:00:00 is already populated
# 2023-05-02 00:00:00 is already populated
# 2023-05-03 00:00:00 is already populated
# 2023-05-04 00:00:00 is already populated
# 2023-05-05 00:00:00 is already populated
# 2023-05-06 00:00:00 is already populated
# 2023-05-07 00:00:00 is already populated
# 1
# date           2023-05-08 00:00:00
# total_music                   16.0
# Name: 1223, dtype: object
# 1
# date           2023-05-09 00:00:00
# total_music                   20.0
# Name: 1224, dtype: object
# 1
# 2
# date           2023-05-10 00:00:00
# total_music                   30.0
# Name: 1225, dtype: object
# 1
# 2
# date           2023-05-11 00:00:00
# total_music                   41.0
# Name: 1226, dtype: object
# 1
# 2
# date           2023-05-12 00:00:00
# total_music                   44.0
# Name: 1227, dtype: object
# 1
# 2
# date           2023-05-13 00:00:00
# total_music                   48.0
# Name: 1228, dtype: object
# 1
# 2
# date           2023-05-14 00:00:00
# total_music                   25.0
# Name: 1229, dtype: object
# 1
# date           2023-05-15 00:00:00
# total_music                   15.0
# Name: 1230, dtype: object
# 1
# date           2023-05-16 00:00:00
# total_music                   20.0
# Name: 1231, dtype: object
# 1
# 2
# date           2023-05-17 00:00:00
# total_music                   27.0
# Name: 1232, dtype: object
# 1
# 2
# date           2023-05-18 00:00:00
# total_music                   30.0
# Name: 1233, dtype: object
# 1
# 2
# date           2023-05-19 00:00:00
# total_music                   49.0
# Name: 1234, dtype: object
# 1
# 2
# 3
# date           2023-05-20 00:00:00
# total_music                   61.0
# Name: 1235, dtype: object
# 1
# 2
# date           2023-05-21 00:00:00
# total_music                   33.0
# Name: 1236, dtype: object
# 1
# date           2023-05-22 00:00:00
# total_music                   14.0
# Name: 1237, dtype: object
# 1
# date           2023-05-23 00:00:00
# total_music                   21.0
# Name: 1238, dtype: object
# 1
# date           2023-05-24 00:00:00
# total_music                   19.0
# Name: 1239, dtype: object
# 1
# date           2023-05-25 00:00:00
# total_music                   15.0
# Name: 1240, dtype: object
# 1
# date           2023-05-26 00:00:00
# total_music                   19.0
# Name: 1241, dtype: object
# 1
# date           2023-05-27 00:00:00
# total_music                   24.0
# Name: 1242, dtype: object
# 1
# date           2023-05-28 00:00:00
# total_music                   20.0
# Name: 1243, dtype: object
# 1
# date           2023-05-29 00:00:00
# total_music                    6.0
# Name: 1244, dtype: object
# 1
# date           2023-05-30 00:00:00
# total_music                   13.0
# Name: 1245, dtype: object
# 1
# date           2023-05-31 00:00:00
# total_music                   21.0
# Name: 1246, dtype: object
# 1
# date           2023-06-01 00:00:00
# total_music                   17.0
# Name: 1247, dtype: object

# %% [markdown]
# Madison Square Garden Scraper

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os
from datetime import date

QUERIED_TEXT = 'madison-square-garden'

# Prep dataframe for all applicable date ranges for which there will be total_{QUERIED_TEXT} count
queried_start_date = pd.to_datetime('2020-01-01') #, format='%Y%m%d')
queried_current_date = date.today()
queried_end_date = pd.to_datetime('2023-06-01') #, format='%Y%m%d')

queried_past_date_range = pd.date_range(start=queried_start_date, end=queried_current_date)
queried_past_date_df = pd.DataFrame({'date': queried_past_date_range})
queried_past_date_df[f'total_{QUERIED_TEXT}_events'] = None
queried_past_date_df = queried_past_date_df[::-1]
queried_past_date_df.reset_index(inplace=True, drop=True)
queried_past_date_df

queried_future_date_range = pd.date_range(start=queried_current_date, end=queried_end_date)
queried_future_date_df = pd.DataFrame({'date': queried_future_date_range})
queried_future_date_df[f'total_{QUERIED_TEXT}_events'] = None
queried_future_date_df

# Set the base URL
past_base_url = 'https://donyc.com/venues/{}/past_events?page={}'
future_base_url = 'https://donyc.com/venues/{}?page={}'

# Verify that file exists
csv_filename = f'donyc_{QUERIED_TEXT}.csv'
if os.path.isfile(csv_filename):
    venue_dates_df = pd.read_csv(csv_filename, parse_dates=['date'])
    queried_past_date_df = venue_dates_df[venue_dates_df['date'].date() < queried_current_date][::-1]
    # queried_past_date_df = venue_dates_df[venue_dates_df['date'] < queried_current_date].sort_values('date', ascending=False)
    queried_past_date_df.reset_index(inplace=True, drop=True)
    queried_future_date_df = venue_dates_df[venue_dates_df['date'] >= queried_current_date]

# %%
# Prepare indexing variables
increment_date = True
increment_url = True
page_num = 1
count = 0
queried_past_date_df_index = 0
logic_complete = False

# Set date info
_date = queried_past_date_df.loc[queried_past_date_df_index, 'date']
year = _date.year
month = _date.month
day = _date.day

# Reminder, in the past loop, the "newer"Dates in code have lower date values
while True:
    # Set key to complete loop

        # if increment_date:
    # # Set date info
    # _date = queried_past_date_df.loc[queried_past_date_df_index, 'date']
    # year = _date.year
    # month = _date.month
    # day = _date.day
        # reset_date = False

        # if increment_url:
    # Set card info
    url = past_base_url.format(QUERIED_TEXT, page_num)
    print(f'{url}')
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    event_cards = soup.select('div[class^="ds-listing event-card"]')
        # reset_url = False

        # While True, loop through every event_cards
        # while True:

    for card in event_cards:
        href = card.find('a')['href']
        year, month, day = [int(x) for x in href.split('/')[2:5] if x.isdigit()]
        event_date = date(year, month, day)
        print(f'card date {event_date}')
        print(f'{_date} of count {count}')

        # If the newest card date value is lower than queried_start_date then initiate emergency brakes
        if event_date < queried_start_date.date():
            logic_complete = True
            break

        # If event_date matches index date, then increment count
        if event_date == _date.date():
            count += 1
    
        # Technically bottom two logics can be combined as !=
        # If event_date is less than index date, add a new count entry for _date and move on
        elif event_date < _date.date():
            queried_past_date_df[queried_past_date_df_index, f'total_{QUERIED_TEXT}_events'] = count

            # While inefficient to sort every time, it allows for pause and resumption of downloads effortlessly
            pd.concat([queried_past_date_df, queried_future_date_df]).sort_values('date', ascending=True).to_csv(csv_filename, index=False)
            
            queried_past_date_df_index += 1
            count = 0

            _date = queried_past_date_df.loc[queried_past_date_df_index, 'date']
            year = _date.year
            month = _date.month
            day = _date.day

        # If event_date is greater than index date, add a new 0 entry for _date and move on
        elif event_date > _date.date():
            queried_past_date_df[queried_past_date_df_index, f'total_{QUERIED_TEXT}_events'] = count
            
            # While inefficient to sort every time, it allows for pause and resumption of downloads effortlessly
            pd.concat([queried_past_date_df, queried_future_date_df]).sort_values('date', ascending=True).to_csv(csv_filename, index=False)
            
            queried_past_date_df_index += 1
            count = 0

            _date = queried_past_date_df.loc[queried_past_date_df_index, 'date']
            year = _date.year
            month = _date.month
            day = _date.day

    if logic_complete:
        break

    # one page is complete, run the next page
    print(page_num)
    page_num += 1
# Out:
# card date 2023-03-02
# 2023-03-03 00:00:00 of count 0
# card date 2023-03-01
# 2023-03-02 00:00:00 of count 0
# card date 2023-02-27
# 2023-03-01 00:00:00 of count 0
# card date 2023-02-26
# 2023-02-28 00:00:00 of count 0
# card date 2023-02-25
# 2023-02-27 00:00:00 of count 0
# card date 2023-02-24
# 2023-02-26 00:00:00 of count 0
# card date 2023-02-21
# 2023-02-25 00:00:00 of count 0
# card date 2023-02-20
# 2023-02-24 00:00:00 of count 0
# card date 2023-02-18
# 2023-02-23 00:00:00 of count 0
# card date 2023-02-14
# 2023-02-22 00:00:00 of count 0
# card date 2023-02-13
# 2023-02-21 00:00:00 of count 0
# card date 2023-02-11
# 2023-02-20 00:00:00 of count 0
# card date 2023-02-10
# 2023-02-19 00:00:00 of count 0
# card date 2023-02-09
# 2023-02-18 00:00:00 of count 0
# card date 2023-02-08
# 2023-02-17 00:00:00 of count 0
# card date 2023-02-06
# 2023-02-16 00:00:00 of count 0
# card date 2023-02-05
# 2023-02-15 00:00:00 of count 0
# card date 2023-02-04
# 2023-02-14 00:00:00 of count 0
# card date 2023-02-02
# 2023-02-13 00:00:00 of count 0
# card date 2023-01-31
# 2023-02-12 00:00:00 of count 0
# card date 2023-01-29
# 2023-02-11 00:00:00 of count 0
# card date 2023-01-28
# 2023-02-10 00:00:00 of count 0
# card date 2023-01-27
# 2023-02-09 00:00:00 of count 0
# card date 2023-01-24
# 2023-02-08 00:00:00 of count 0
# card date 2023-01-23
# 2023-02-07 00:00:00 of count 0
# 1
